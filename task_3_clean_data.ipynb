# %% [markdown]
# # import packages

# %%
import json
import re
import numpy as np
import pandas as pd
from write_load_data import load_data
from write_load_data import write_to_json

# %%
# load 'movie_dictionaries.json' and store as a variable named df. 
# If 'movie_dictionaries.json' does not exist in the directory this function will fail.
df = load_data('movie_dictionaries.json')

# %%
# [x for x in df if x['title']=='sacred planet']

# %%
# check the length of the dataframe loaded.
len(df)
# Out:
# 447

# %%
#[clean] Testing to see if we are getting 'clean' versions of dictionaries.
# NOTE: To get the data format more standardized, all string fields are lower case.
[(index, x) for index,x in enumerate(df) if x['title']=="the vanishing prairie"]
# Out:
# [(24,
#   {'title': 'the vanishing prairie',
#    'Produced by': ['ben sharpsteen', 'walt disney'],
#    'Written by': ['james algar', 'winston hibler'],
#    'Narrated by': 'winston hibler',
#    'Music by': 'paul j. smith',
#    'Cinematography': 'n. paul kenworthy',
#    'Edited by': 'lloyd l. richardson',
#    'Production company': 'walt disney productions',
#    'Distributed by': 'buena vista distribution',
#    'Release date': ['august 17, 1954 ( 1954-08-17 )'],
#    'Running time': ['60 minutes (vhs version)', '71 minutes (original)'],
#    'Country': 'united states',
#    'Language': 'english',
#    'Box office': '$1.75 million (us and canadian rentals)'})]

# %%
# [clean] Testing to  see if we are getting 'clean' versions of dictionaries.
df[0:5]
# Out:
# [{'title': 'academy award review of walt disney cartoons',
#   'Production company': 'walt disney productions',
#   'Release date': ['may 19, 1937 ( 1937-05-19 )'],
#   'Running time': '41 minutes (74 minutes 1966 release)',
#   'Country': 'united states',
#   'Language': 'english',
#   'Box office': '$45.472'},
#  {'title': 'snow white and the seven dwarfs',
#   'Directed by': ['david hand (supervising)',
#    'william cottrell',
#    'wilfred jackson',
#    'larry morey',
#    'perce pearce',
#    'ben sharpsteen'],
#   'Produced by': 'walt disney',
#   'Written by': ['ted sears',
#    'richard creedon',
#    'otto englander',
#    'dick rickard',
#    'earl hurd',
#    'merrill de maris',
#    'dorothy ann blank',
#    'webb smith'],
#   'Based on': ['snow white', 'brothers grimm'],
#   'Starring': ['adriana caselotti',
#    'lucille la verne',
#    'harry stockwell',
#    'roy atwell',
#    'pinto colvig',
#    'otis harlan',
#    'scotty mattraw',
#    'billy gilbert',
#    'eddie collins',
#    'moroni olsen',
#    'stuart buchanan'],
#   'Music by': ['frank churchill', 'paul smith', 'leigh harline'],
#   'Production company': 'walt disney productions',
#   'Distributed by': 'rko radio pictures',
#   'Release date': ['december 21, 1937 ( 1937-12-21 ) ( carthay circle theatre , los angeles , ca , premiere)'],
#   'Running time': '83 minutes',
#   'Country': 'united states',
#   'Language': 'english',
#   'Budget': '$1.49 million',
#   'Box office': '$418 million'},
#  {'title': 'pinocchio',
#   'Directed by': ['ben sharpsteen',
#    'hamilton luske',
#    'bill roberts',
#    'norman ferguson',
#    'jack kinney',
#    'wilfred jackson',
#    't. hee'],
#   'Produced by': 'walt disney',
#   'Story by': ['ted sears',
#    'otto englander',
#    'webb smith',
#    'william cottrell',
#    'joseph sabo',
#    'erdman penner',
#    'aurelius battaglia'],
#   'Based on': ['the adventures of pinocchio', 'carlo collodi'],
#   'Starring': ['cliff edwards',
#    'dickie jones',
#    'christian rub',
#    'walter catlett',
#    'charles judels',
#    'evelyn venable',
#    'frankie darro',
#    'clarence nash',
#    'mel blanc'],
#   'Music by': ['leigh harline', 'paul j. smith'],
#   'Production company': 'walt disney productions',
#   'Distributed by': 'rko radio pictures',
#   'Release date': ['february 7, 1940 ( 1940-02-07 ) ( center theatre )',
#    'february 23, 1940 ( 1940-02-23 ) (united states)'],
#   'Running time': '88 minutes',
#   'Country': 'united states',
#   'Language': 'english',
#   'Budget': '$2.6 million',
#   'Box office': '$164 million'},
#  {'title': 'fantasia',
#   'Directed by': ['samuel armstrong',
#    'james algar',
#    'bill roberts',
#    'paul satterfield',
#    'ben sharpsteen',
#    'david d. hand',
#    'hamilton luske',
#    'jim handley',
#    'ford beebe',
#    't. hee',
#    'norman ferguson',
#    'wilfred jackson'],
#   'Produced by': ['walt disney', 'ben sharpsteen'],
#   'Story by': ['joe grant', 'dick huemer'],
#   'Starring': ['leopold stokowski', 'deems taylor'],
#   'Narrated by': 'deems taylor',
#   'Music by': 'see program',
#   'Cinematography': 'james wong howe',
#   'Production company': 'walt disney productions',
#   'Distributed by': 'rko radio pictures',
#   'Release date': ['november 13, 1940 ( 1940-11-13 )'],
#   'Running time': '126 minutes',
#   'Country': 'united states',
#   'Language': 'english',
#   'Budget': '$2.28 million',
#   'Box office': '$76.4–$83.3 million'},
#  {'title': 'the reluctant dragon',
#   'Directed by': ['alfred werker',
#    'hamilton luske',
#    'jack cutting',
#    'ub iwerks',
#    'jack kinney'],
#   'Produced by': 'walt disney',
#   'Written by': ['ted sears',
#    'al perkins',
#    'bill cottrell',
#    'harry clork',
#    'robert benchley',
#    'kenneth grahame',
#    't. hee',
#    'joe grant',
#    'dick huemer'],
#   'Starring': ['robert benchley', 'frances gifford', 'nana bryant'],
#   'Music by': ['frank churchill', 'larry morey'],
#   'Cinematography': 'bert giennon',
#   'Edited by': 'paul weatherwax',
#   'Production company': 'walt disney productions',
#   'Distributed by': 'rko radio pictures',
#   'Release date': ['june 20, 1941 ( 1941-06-20 )'],
#   'Running time': '74 minutes',
#   'Country': 'united states',
#   'Language': 'english',
#   'Budget': '$600,000',
#   'Box office': '$960,000 (worldwide rentals)'}]

# %% [markdown]
# # Clean the Data!
#
# - ~~Standarize subscripts, Clean up references ~~
#     - This was completed in 'task_2_scrape_movie_webpages.ipynb'. In the functions that created the movie dictionaries.
# - Standarize Time
#     - Convert running time to an integer
#     - convert data as date-time object
# - Standarize Money
#     - Convert budget
#     - box office to numbers
# - Standarize 'Starring' make a list

# %%
# Standardize Time
# Convert running time to an integer.
# Let's see how 'One Little Indian' turned out.
little_indian = [x for x in df if x['title']=="one little indian"]
little_indian
# Out:
# [{'title': 'one little indian',
#   'Directed by': 'bernard mceveety',
#   'Produced by': 'winston hibler',
#   'Written by': 'harry spalding',
#   'Starring': ['james garner',
#    'vera miles',
#    'pat hingle',
#    'morgan woodward',
#    'jodie foster'],
#   'Music by': 'jerry goldsmith',
#   'Cinematography': 'charles f. wheeler',
#   'Edited by': 'robert stafford',
#   'Production company': 'walt disney productions',
#   'Distributed by': 'buena vista distribution',
#   'Release date': ['june 20, 1973 ( 1973-06-20 )'],
#   'Running time': '90 minutes',
#   'Country': 'united states',
#   'Language': 'english',
#   'Box office': '$2 million'}]

# %%
# Navigate into the Running time value of 'One Little Indian'
running_time = little_indian[0]['Running time']
running_time
# Out:
# '90 minutes'

# %%
# How can we clean up the 'Running time' value to be an integer?
# Replace space (' ') and 'Minutes' with no values. 
# wrap the code with int() to change the type from string to an integer.
int(running_time.replace(' ', "").replace('minutes', ""))
# Out:
# 90

# %%
# How many movies have the 'Running time' field
movies_with_runtime = [x for x in df if 'Running time' in x]
len(movies_with_runtime)
# Out:
# 435

# %%
# another way to get the running time field from df. x.get(field_name)
# len([x.get('Running time') for x in df if x.get('Running time') is not None])

# %%
# strip running time if it is a string at '' 'min' (include the space so you don't have to strip it later). 
# movies_with_runtime = [{'title': x['title'], 'Running time': x['Running time'].split(' min', 1)[0]} if type(x['Running time']) is str else {'title':x['title']} for x in  movies_with_runtime ]
# movies_with_runtime

# %%
# remove the movies that don't have the runtime as a string:
# NOTE: '-' is a HYPHEN will take a copy of the output character to use in the split below.
# [{'title': x['title'], 'Running time': x['Running time'].split(' min', 1)[0]} for x in movies_with_runtime if x['title']=='zorro']

# %%
movies_with_runtime_int = [{'title': x['title'], 'Running time': int(x['Running time'].split(' min', 1)[0].split('–')[0])} for x in  movies_with_runtime if type(x['Running time']) is str]
movies_with_runtime_int
# Out:
# [{'title': 'academy award review of walt disney cartoons', 'Running time': 41},
#  {'title': 'snow white and the seven dwarfs', 'Running time': 83},
#  {'title': 'pinocchio', 'Running time': 88},
#  {'title': 'fantasia', 'Running time': 126},
#  {'title': 'the reluctant dragon', 'Running time': 74},
#  {'title': 'dumbo', 'Running time': 64},
#  {'title': 'bambi', 'Running time': 70},
#  {'title': 'saludos amigos', 'Running time': 42},
#  {'title': 'victory through air power', 'Running time': 65},
#  {'title': 'the three caballeros', 'Running time': 71},
#  {'title': 'make mine music', 'Running time': 75},
#  {'title': 'song of the south', 'Running time': 94},
#  {'title': 'fun and fancy free', 'Running time': 73},
#  {'title': 'melody time', 'Running time': 75},
#  {'title': 'so dear to my heart', 'Running time': 82},
#  {'title': 'the adventures of ichabod andmr. toad', 'Running time': 68},
#  {'title': 'cinderella', 'Running time': 74},
#  {'title': 'treasure island', 'Running time': 96},
#  {'title': 'alice in wonderland', 'Running time': 75},
#  {'title': 'the story of robin hood andhis merrie men', 'Running time': 84},
#  {'title': 'peter pan', 'Running time': 77},
#  {'title': 'the sword and the rose', 'Running time': 92},
#  {'title': 'the living desert', 'Running time': 69},
#  {'title': 'rob roy, the highland rogue', 'Running time': 81},
#  {'title': '20,000 leagues under the sea', 'Running time': 127},
#  {'title': 'davy crockett, king of the wild frontier', 'Running time': 92},
#  {'title': 'lady and the tramp', 'Running time': 76},
#  {'title': 'the african lion', 'Running time': 75},
#  {'title': 'the littlest outlaw', 'Running time': 73},
#  {'title': 'the great locomotive chase', 'Running time': 85},
#  {'title': 'davy crockett and the river pirates', 'Running time': 81},
#  {'title': 'secrets of life', 'Running time': 70},
#  {'title': 'westward ho the wagons!', 'Running time': 90},
#  {'title': 'johnny tremain', 'Running time': 80},
#  {'title': 'perri', 'Running time': 75},
#  {'title': 'old yeller', 'Running time': 83},
#  {'title': 'the light in the forest', 'Running time': 83},
#  {'title': 'white wilderness', 'Running time': 72},
#  {'title': 'tonka', 'Running time': 97},
#  {'title': 'sleeping beauty', 'Running time': 75},
#  {'title': 'the shaggy dog', 'Running time': 104},
#  {'title': "darby o'gill and the little people", 'Running time': 93},
#  {'title': 'zorro', 'Running time': 22},
#  {'title': 'third man on the mountain', 'Running time': 105},
#  {'title': 'toby tyler', 'Running time': 95},
#  {'title': 'kidnapped', 'Running time': 97},
#  {'title': 'pollyanna', 'Running time': 134},
#  {'title': 'zorro', 'Running time': 22},
#  {'title': 'jungle cat', 'Running time': 69},
#  {'title': 'ten who dared', 'Running time': 92},
#  {'title': 'swiss family robinson', 'Running time': 126},
#  {'title': 'one hundred and one dalmatians', 'Running time': 79},
#  {'title': 'the absent-minded professor', 'Running time': 97},
#  {'title': 'the parent trap (simply known as the parent trap: a laugh affair)',
#   'Running time': 128},
#  {'title': 'nikki, wild dog of the north', 'Running time': 74},
#  {'title': 'greyfriars bobby', 'Running time': 91},
#  {'title': 'babes in toyland', 'Running time': 105},
#  {'title': 'moon pilot', 'Running time': 98},
#  {'title': 'bon voyage!', 'Running time': 130},
#  {'title': 'big red', 'Running time': 89},
#  {'title': 'almost angels', 'Running time': 93},
#  {'title': 'the legend of lobo', 'Running time': 67},
#  {'title': 'in search of the castaways', 'Running time': 98},
#  {'title': 'son of flubber', 'Running time': 100},
#  {'title': 'miracle of the white stallions', 'Running time': 118},
#  {'title': 'savage sam', 'Running time': 103},
#  {'title': 'summer magic', 'Running time': 110},
#  {'title': 'the incredible journey', 'Running time': 80},
#  {'title': 'the sword in the stone', 'Running time': 79},
#  {'title': 'a tiger walks', 'Running time': 91},
#  {'title': 'the misadventures of merlin jones', 'Running time': 91},
#  {'title': 'the three lives of thomasina', 'Running time': 97},
#  {'title': 'the moon-spinners', 'Running time': 118},
#  {'title': 'mary poppins', 'Running time': 139},
#  {'title': 'emil and the detectives', 'Running time': 92},
#  {'title': 'those calloways', 'Running time': 131},
#  {'title': "the monkey's uncle", 'Running time': 87},
#  {'title': 'that darn cat!', 'Running time': 116},
#  {'title': 'the ugly dachshund', 'Running time': 93},
#  {'title': 'lt. robin crusoe, u.s.n.', 'Running time': 110},
#  {'title': 'the fighting prince of donegal', 'Running time': 110},
#  {'title': 'follow me, boys!', 'Running time': 131},
#  {'title': 'monkeys, go home!', 'Running time': 101},
#  {'title': 'the adventures of bullwhip griffin', 'Running time': 108},
#  {'title': 'the gnome-mobile', 'Running time': 84},
#  {'title': 'the jungle book', 'Running time': 78},
#  {'title': 'charlie, the lonesome cougar', 'Running time': 75},
#  {'title': "blackbeard's ghost", 'Running time': 106},
#  {'title': 'the one and only, genuine, original family band',
#   'Running time': 110},
#  {'title': 'never a dull moment', 'Running time': 99},
#  {'title': 'the horse in the gray flannel suit', 'Running time': 113},
#  {'title': 'the love bug', 'Running time': 108},
#  {'title': 'smith!', 'Running time': 112},
#  {'title': 'rascal', 'Running time': 93},
#  {'title': 'the computer wore tennis shoes', 'Running time': 91},
#  {'title': 'king of the grizzlies', 'Running time': 93},
#  {'title': 'the boatniks', 'Running time': 100},
#  {'title': 'the wild country', 'Running time': 100},
#  {'title': 'the aristocats', 'Running time': 79},
#  {'title': 'the barefoot executive', 'Running time': 96},
#  {'title': 'scandalous john', 'Running time': 113},
#  {'title': 'the million dollar duck', 'Running time': 89},
#  {'title': 'the biscuit eater', 'Running time': 92},
#  {'title': "now you see him, now you don't", 'Running time': 88},
#  {'title': 'napoleon and samantha', 'Running time': 92},
#  {'title': 'run, cougar, run', 'Running time': 87},
#  {'title': 'snowball express', 'Running time': 93},
#  {'title': "the world's greatest athlete", 'Running time': 93},
#  {'title': 'charley and the angel', 'Running time': 93},
#  {'title': 'one little indian', 'Running time': 90},
#  {'title': 'robin hood', 'Running time': 83},
#  {'title': 'superdad', 'Running time': 96},
#  {'title': 'herbie rides again', 'Running time': 88},
#  {'title': 'the bears and i', 'Running time': 89},
#  {'title': 'the castaway cowboy', 'Running time': 91},
#  {'title': 'the island at the top of the world', 'Running time': 93},
#  {'title': 'the strongest man in the world', 'Running time': 92},
#  {'title': 'escape to witch mountain', 'Running time': 97},
#  {'title': 'the apple dumpling gang', 'Running time': 100},
#  {'title': 'one of our dinosaurs is missing', 'Running time': 100},
#  {'title': "the best of walt disney's true-life adventures",
#   'Running time': 89},
#  {'title': 'ride a wild pony', 'Running time': 91},
#  {'title': 'no deposit, no return', 'Running time': 112},
#  {'title': 'treasure of matecumbe', 'Running time': 115},
#  {'title': 'gus', 'Running time': 95},
#  {'title': 'the shaggy d.a.', 'Running time': 91},
#  {'title': 'freaky friday: the movie', 'Running time': 95},
#  {'title': 'escape from the dark', 'Running time': 104},
#  {'title': 'the many adventures of winnie the pooh', 'Running time': 74},
#  {'title': 'a tale of two critters', 'Running time': 48},
#  {'title': 'the rescuers', 'Running time': 77},
#  {'title': 'herbie goes to monte carlo', 'Running time': 104},
#  {'title': "pete's dragon", 'Running time': 128},
#  {'title': 'candleshoe', 'Running time': 101},
#  {'title': 'return from witch mountain', 'Running time': 94},
#  {'title': 'the cat from outer space', 'Running time': 104},
#  {'title': 'hot lead and cold feet', 'Running time': 90},
#  {'title': 'the north avenue irregulars', 'Running time': 100},
#  {'title': 'the apple dumpling gang rides again', 'Running time': 88},
#  {'title': 'unidentified flying oddball', 'Running time': 93},
#  {'title': 'the black hole', 'Running time': 98},
#  {'title': 'the omega connection', 'Running time': 100},
#  {'title': 'midnight madness', 'Running time': 112},
#  {'title': 'the watcher in the woods', 'Running time': 84},
#  {'title': 'herbie goes bananas', 'Running time': 98},
#  {'title': "the last flight of noah's ark", 'Running time': 97},
#  {'title': 'popeye', 'Running time': 114},
#  {'title': 'the devil and max devlin', 'Running time': 96},
#  {'title': 'amy', 'Running time': 100},
#  {'title': 'dragonslayer', 'Running time': 109},
#  {'title': 'the fox and the hound', 'Running time': 83},
#  {'title': 'condorman', 'Running time': 90},
#  {'title': 'night crossing', 'Running time': 107},
#  {'title': 'tron', 'Running time': 96},
#  {'title': 'tex', 'Running time': 103},
#  {'title': 'trenchcoat', 'Running time': 91},
#  {'title': 'something wicked this way comes', 'Running time': 95},
#  {'title': 'never cry wolf', 'Running time': 105},
#  {'title': 'return to oz', 'Running time': 113},
#  {'title': 'the black cauldron', 'Running time': 80},
#  {'title': 'the journey of natty gann', 'Running time': 101},
#  {'title': 'one magic christmas', 'Running time': 89},
#  {'title': 'the great mouse detective', 'Running time': 74},
#  {'title': 'flight of the navigator', 'Running time': 90},
#  {'title': 'benji the hunted', 'Running time': 89},
#  {'title': 'the man from snowy river ii', 'Running time': 110},
#  {'title': 'oliver & company', 'Running time': 74},
#  {'title': 'honey, i shrunk the kids', 'Running time': 93},
#  {'title': 'cheetah', 'Running time': 84},
#  {'title': 'the little mermaid', 'Running time': 83},
#  {'title': 'ducktales the movie: treasure of the lost lamp',
#   'Running time': 69},
#  {'title': 'the rescuers down under', 'Running time': 77},
#  {'title': 'white fang', 'Running time': 107},
#  {'title': 'shipwrecked', 'Running time': 93},
#  {'title': "wild hearts can't be broken", 'Running time': 88},
#  {'title': 'the rocketeer', 'Running time': 108},
#  {'title': 'beauty and the beast', 'Running time': 84},
#  {'title': 'newsies', 'Running time': 121},
#  {'title': 'honey, i blew up the kid', 'Running time': 89},
#  {'title': 'the mighty ducks', 'Running time': 104},
#  {'title': 'aladdin', 'Running time': 90},
#  {'title': 'the muppet christmas carol', 'Running time': 86},
#  {'title': 'homeward bound: the incredible journey', 'Running time': 84},
#  {'title': 'a far off place', 'Running time': 108},
#  {'title': 'the adventures of huck finn', 'Running time': 107},
#  {'title': 'hocus pocus', 'Running time': 96},
#  {'title': 'cool runnings', 'Running time': 98},
#  {'title': 'the three musketeers', 'Running time': 105},
#  {'title': 'iron will', 'Running time': 108},
#  {'title': 'blank check', 'Running time': 94},
#  {'title': 'd2: the mighty ducks', 'Running time': 106},
#  {'title': 'white fang 2: myth of the white wolf', 'Running time': 102},
#  {'title': 'the lion king', 'Running time': 88},
#  {'title': 'angels in the outfield', 'Running time': 102},
#  {'title': "squanto: a warrior's tale", 'Running time': 102},
#  {'title': 'the santa clause', 'Running time': 97},
#  {'title': "rudyard kipling's the jungle book", 'Running time': 111},
#  {'title': 'heavyweights', 'Running time': 100},
#  {'title': 'man of the house', 'Running time': 96},
#  {'title': 'tall tale', 'Running time': 98},
#  {'title': 'a goofy movie', 'Running time': 78},
#  {'title': 'pocahontas', 'Running time': 81},
#  {'title': 'operation dumbo drop', 'Running time': 108},
#  {'title': "a kid in king arthur's court", 'Running time': 89},
#  {'title': 'the big green', 'Running time': 99},
#  {'title': 'frank and ollie', 'Running time': 89},
#  {'title': 'toy story', 'Running time': 81},
#  {'title': 'tom and huck', 'Running time': 92},
#  {'title': 'muppet treasure island', 'Running time': 100},
#  {'title': 'homeward bound ii:lost in san francisco', 'Running time': 89},
#  {'title': 'james and the giant peach', 'Running time': 79},
#  {'title': 'the hunchback of notre dame', 'Running time': 91},
#  {'title': 'first kid', 'Running time': 101},
#  {'title': 'd3: the mighty ducks', 'Running time': 104},
#  {'title': '101 dalmatians', 'Running time': 103},
#  {'title': 'that darn cat', 'Running time': 86},
#  {'title': 'jungle 2 jungle', 'Running time': 105},
#  {'title': 'hercules', 'Running time': 93},
#  {'title': 'george of the jungle', 'Running time': 92},
#  {'title': 'air bud', 'Running time': 98},
#  {'title': 'rocketman', 'Running time': 95},
#  {'title': 'flubber', 'Running time': 93},
#  {'title': 'mr. magoo', 'Running time': 87},
#  {'title': 'meet the deedles', 'Running time': 93},
#  {'title': 'mulan', 'Running time': 87},
#  {'title': 'the parent trap', 'Running time': 128},
#  {'title': "i'll be home for christmas", 'Running time': 86},
#  {'title': "a bug's life", 'Running time': 95},
#  {'title': 'mighty joe young', 'Running time': 114},
#  {'title': 'my favorite martian', 'Running time': 93},
#  {'title': "doug's 1st movie", 'Running time': 83},
#  {'title': 'endurance', 'Running time': 83},
#  {'title': 'tarzan', 'Running time': 88},
#  {'title': 'inspector gadget', 'Running time': 78},
#  {'title': 'the straight story', 'Running time': 112},
#  {'title': 'toy story 2', 'Running time': 92},
#  {'title': 'fantasia 2000', 'Running time': 74},
#  {'title': 'the tigger movie', 'Running time': 78},
#  {'title': 'dinosaur', 'Running time': 82},
#  {'title': 'the kid', 'Running time': 104},
#  {'title': 'remember the titans', 'Running time': 113},
#  {'title': '102 dalmatians', 'Running time': 100},
#  {'title': "the emperor's new groove", 'Running time': 78},
#  {'title': "recess: school's out", 'Running time': 83},
#  {'title': 'atlantis: the lost empire', 'Running time': 96},
#  {'title': 'the princess diaries', 'Running time': 115},
#  {'title': "max keeble's big move", 'Running time': 86},
#  {'title': 'monsters, inc.', 'Running time': 92},
#  {'title': 'snow dogs', 'Running time': 99},
#  {'title': 'return to never land', 'Running time': 73},
#  {'title': 'the rookie', 'Running time': 128},
#  {'title': 'lilo & stitch', 'Running time': 85},
#  {'title': 'the country bears', 'Running time': 88},
#  {'title': 'spirited away', 'Running time': 125},
#  {'title': 'tuck everlasting', 'Running time': 96},
#  {'title': 'the santa clause 2', 'Running time': 104},
#  {'title': 'treasure planet', 'Running time': 95},
#  {'title': 'the jungle book 2', 'Running time': 72},
#  {'title': "piglet's big movie", 'Running time': 75},
#  {'title': 'ghosts of the abyss', 'Running time': 61},
#  {'title': 'holes', 'Running time': 117},
#  {'title': 'the lizzie mcguire movie', 'Running time': 94},
#  {'title': 'finding nemo', 'Running time': 100},
#  {'title': 'pirates of the caribbean:the curse of the black pearl',
#   'Running time': 142},
#  {'title': 'freaky friday', 'Running time': 97},
#  {'title': 'brother bear', 'Running time': 85},
#  {'title': 'the haunted mansion', 'Running time': 86},
#  {'title': 'the young black stallion', 'Running time': 50},
#  {'title': "teacher's pet", 'Running time': 74},
#  {'title': 'miracle', 'Running time': 136},
#  {'title': 'confessions of a teenagedrama queen', 'Running time': 89},
#  {'title': 'home on the range', 'Running time': 76},
#  {'title': 'sacred planet', 'Running time': 40},
#  {'title': 'around the world in 80 days', 'Running time': 120},
#  {'title': "america's heart and soul", 'Running time': 84},
#  {'title': 'the princess diaries 2:royal engagement', 'Running time': 113},
#  {'title': 'the incredibles', 'Running time': 115},
#  {'title': 'national treasure', 'Running time': 131},
#  {'title': 'aliens of the deep', 'Running time': 100},
#  {'title': "pooh's heffalump movie", 'Running time': 68},
#  {'title': 'the pacifier', 'Running time': 95},
#  {'title': 'ice princess', 'Running time': 97},
#  {'title': 'herbie: fully loaded', 'Running time': 101},
#  {'title': "howl's moving castle", 'Running time': 119},
#  {'title': 'sky high', 'Running time': 100},
#  {'title': 'valiant', 'Running time': 76},
#  {'title': 'the greatest game ever played', 'Running time': 120},
#  {'title': 'chicken little', 'Running time': 81},
#  {'title': 'the chronicles of narnia:the lion, the witch and the wardrobe',
#   'Running time': 143},
#  {'title': 'glory road', 'Running time': 106},
#  {'title': 'roving mars', 'Running time': 40},
#  {'title': 'eight below', 'Running time': 120},
#  {'title': 'the shaggy dog', 'Running time': 99},
#  {'title': 'the wild', 'Running time': 82},
#  {'title': 'cars', 'Running time': 117},
#  {'title': "pirates of the caribbean:  dead man's chest", 'Running time': 150},
#  {'title': 'invincible', 'Running time': 104},
#  {'title': 'the nightmare before christmas', 'Running time': 76},
#  {'title': 'the santa clause 3:the escape clause', 'Running time': 92},
#  {'title': 'bridge to terabithia', 'Running time': 95},
#  {'title': 'meet the robinsons', 'Running time': 94},
#  {'title': "pirates of the caribbean:  at world's end", 'Running time': 167},
#  {'title': 'ratatouille', 'Running time': 111},
#  {'title': 'underdog', 'Running time': 82},
#  {'title': 'the pixar story', 'Running time': 87},
#  {'title': 'the game plan', 'Running time': 110},
#  {'title': 'enchanted', 'Running time': 107},
#  {'title': 'national treasure: book of secrets', 'Running time': 124},
#  {'title': 'hannah montana and miley cyrus:best of both worlds concert',
#   'Running time': 74},
#  {'title': 'college road trip', 'Running time': 83},
#  {'title': 'the chronicles of narnia: prince caspian', 'Running time': 150},
#  {'title': 'wall-e', 'Running time': 97},
#  {'title': 'beverly hills chihuahua', 'Running time': 91},
#  {'title': 'morning light', 'Running time': 100},
#  {'title': 'bolt', 'Running time': 96},
#  {'title': 'bedtime stories', 'Running time': 99},
#  {'title': 'the secret of the magic gourd', 'Running time': 85},
#  {'title': 'race to witch mountain', 'Running time': 98},
#  {'title': 'hannah montana: the movie', 'Running time': 97},
#  {'title': 'up', 'Running time': 96},
#  {'title': 'g-force', 'Running time': 90},
#  {'title': 'ponyo', 'Running time': 101},
#  {'title': 'the book of masters', 'Running time': 101},
#  {'title': 'a christmas carol', 'Running time': 96},
#  {'title': 'old dogs', 'Running time': 88},
#  {'title': 'the princess and the frog', 'Running time': 97},
#  {'title': 'alice in wonderland', 'Running time': 108},
#  {'title': 'prince of persia: the sands of time', 'Running time': 116},
#  {'title': 'toy story 3', 'Running time': 103},
#  {'title': "the sorcerer's apprentice", 'Running time': 109},
#  {'title': 'tales from earthsea', 'Running time': 115},
#  {'title': 'the crimson wing: mystery of the flamingos', 'Running time': 74},
#  {'title': 'secretariat', 'Running time': 123},
#  {'title': 'do dooni chaar', 'Running time': 108},
#  {'title': 'tangled', 'Running time': 100},
#  {'title': "the boys: the sherman brothers' story", 'Running time': 101},
#  {'title': 'tron: legacy', 'Running time': 125},
#  {'title': 'lilly the witch:the journey to mandolan', 'Running time': 90},
#  {'title': 'mars needs moms', 'Running time': 88},
#  {'title': 'zokkomon', 'Running time': 109},
#  {'title': 'african cats', 'Running time': 89},
#  {'title': 'prom', 'Running time': 104},
#  {'title': 'pirates of the caribbean:on stranger tides', 'Running time': 137},
#  {'title': 'cars 2', 'Running time': 106},
#  {'title': 'winnie the pooh', 'Running time': 69},
#  {'title': 'the muppets', 'Running time': 103},
#  {'title': 'arrietty', 'Running time': 95},
#  {'title': 'john carter', 'Running time': 132},
#  {'title': 'chimpanzee', 'Running time': 77},
#  {'title': 'arjun: the warrior prince', 'Running time': 96},
#  {'title': 'brave', 'Running time': 93},
#  {'title': 'the odd life of timothy green', 'Running time': 104},
#  {'title': 'frankenweenie', 'Running time': 87},
#  {'title': 'wreck-it ralph', 'Running time': 101},
#  {'title': 'oz the great and powerful', 'Running time': 130},
#  {'title': 'wings of life', 'Running time': 77},
#  {'title': 'monsters university', 'Running time': 104},
#  {'title': 'the lone ranger', 'Running time': 149},
#  {'title': 'planes', 'Running time': 92},
#  {'title': 'frozen', 'Running time': 102},
#  {'title': 'saving mr. banks', 'Running time': 125},
#  {'title': 'muppets most wanted', 'Running time': 107},
#  {'title': 'bears', 'Running time': 77},
#  {'title': 'million dollar arm', 'Running time': 124},
#  {'title': 'maleficent', 'Running time': 97},
#  {'title': 'planes: fire & rescue', 'Running time': 84},
#  {'title': 'khoobsurat', 'Running time': 127},
#  {'title': 'alexander and the terrible, horrible, no good, very bad day',
#   'Running time': 81},
#  {'title': 'big hero 6', 'Running time': 102},
#  {'title': 'into the woods', 'Running time': 124},
#  {'title': 'mcfarland, usa', 'Running time': 129},
#  {'title': 'cinderella', 'Running time': 106},
#  {'title': 'monkey kingdom', 'Running time': 82},
#  {'title': 'tomorrowland', 'Running time': 130},
#  {'title': 'inside out', 'Running time': 95},
#  {'title': 'abcd 2', 'Running time': 154},
#  {'title': 'the good dinosaur', 'Running time': 94},
#  {'title': 'the finest hours', 'Running time': 117},
#  {'title': 'zootopia', 'Running time': 108},
#  {'title': 'the jungle book', 'Running time': 106},
#  {'title': 'tini: the movie', 'Running time': 98},
#  {'title': 'alice through the looking glass', 'Running time': 114},
#  {'title': 'finding dory', 'Running time': 97},
#  {'title': 'the bfg', 'Running time': 117},
#  {'title': "pete's dragon", 'Running time': 103},
#  {'title': 'queen of katwe', 'Running time': 124},
#  {'title': 'moana', 'Running time': 107},
#  {'title': 'dangal', 'Running time': 161},
#  {'title': 'march of the penguins', 'Running time': 80},
#  {'title': 'beauty and the beast', 'Running time': 129},
#  {'title': 'born in china', 'Running time': 76},
#  {'title': 'pirates of the caribbean:dead men tell no tales',
#   'Running time': 129},
#  {'title': 'cars 3', 'Running time': 102},
#  {'title': 'jagga jasoos', 'Running time': 162},
#  {'title': 'coco', 'Running time': 105},
#  {'title': 'a wrinkle in time', 'Running time': 109},
#  {'title': 'incredibles 2', 'Running time': 118},
#  {'title': 'christopher robin', 'Running time': 104},
#  {'title': 'the nutcracker and the four realms', 'Running time': 99},
#  {'title': 'ralph breaks the internet', 'Running time': 112},
#  {'title': 'mary poppins returns', 'Running time': 131},
#  {'title': 'dumbo', 'Running time': 112},
#  {'title': 'penguins', 'Running time': 76},
#  {'title': 'aladdin', 'Running time': 128},
#  {'title': 'toy story 4', 'Running time': 100},
#  {'title': 'the lion king', 'Running time': 118},
#  {'title': 'maleficent: mistress of evil', 'Running time': 119},
#  {'title': 'lady and the tramp', 'Running time': 104},
#  {'title': 'noelle', 'Running time': 100},
#  {'title': 'frozen ii', 'Running time': 103},
#  {'title': 'togo', 'Running time': 114},
#  {'title': 'timmy failure: mistakes were made', 'Running time': 99},
#  {'title': 'onward', 'Running time': 102},
#  {'title': 'stargirl', 'Running time': 107},
#  {'title': 'dolphin reef', 'Running time': 78},
#  {'title': 'elephant', 'Running time': 89},
#  {'title': 'artemis fowl', 'Running time': 95},
#  {'title': 'hamilton', 'Running time': 160},
#  {'title': 'black is king', 'Running time': 85},
#  {'title': 'magic camp', 'Running time': 100},
#  {'title': 'the one and only ivan', 'Running time': 95},
#  {'title': 'mulan', 'Running time': 115},
#  {'title': 'godmothered', 'Running time': 113},
#  {'title': 'safety', 'Running time': 119},
#  {'title': 'soul', 'Running time': 101},
#  {'title': 'flora & ulysses', 'Running time': 95},
#  {'title': 'raya and the last dragon', 'Running time': 107},
#  {'title': 'night at the museum', 'Running time': 306}]

# %%
# How many movies have a 'Running time' value that is an integer? 428/434
len(movies_with_runtime_int)
# Out:
# 428

# %%
# Store the titles of movies with 'Running time' as an int into a list named title_runtime_int.
title_runtime_int = [x['title'] for x in movies_with_runtime_int]
title_runtime_int
# Out:
# ['academy award review of walt disney cartoons',
#  'snow white and the seven dwarfs',
#  'pinocchio',
#  'fantasia',
#  'the reluctant dragon',
#  'dumbo',
#  'bambi',
#  'saludos amigos',
#  'victory through air power',
#  'the three caballeros',
#  'make mine music',
#  'song of the south',
#  'fun and fancy free',
#  'melody time',
#  'so dear to my heart',
#  'the adventures of ichabod andmr. toad',
#  'cinderella',
#  'treasure island',
#  'alice in wonderland',
#  'the story of robin hood andhis merrie men',
#  'peter pan',
#  'the sword and the rose',
#  'the living desert',
#  'rob roy, the highland rogue',
#  '20,000 leagues under the sea',
#  'davy crockett, king of the wild frontier',
#  'lady and the tramp',
#  'the african lion',
#  'the littlest outlaw',
#  'the great locomotive chase',
#  'davy crockett and the river pirates',
#  'secrets of life',
#  'westward ho the wagons!',
#  'johnny tremain',
#  'perri',
#  'old yeller',
#  'the light in the forest',
#  'white wilderness',
#  'tonka',
#  'sleeping beauty',
#  'the shaggy dog',
#  "darby o'gill and the little people",
#  'zorro',
#  'third man on the mountain',
#  'toby tyler',
#  'kidnapped',
#  'pollyanna',
#  'zorro',
#  'jungle cat',
#  'ten who dared',
#  'swiss family robinson',
#  'one hundred and one dalmatians',
#  'the absent-minded professor',
#  'the parent trap (simply known as the parent trap: a laugh affair)',
#  'nikki, wild dog of the north',
#  'greyfriars bobby',
#  'babes in toyland',
#  'moon pilot',
#  'bon voyage!',
#  'big red',
#  'almost angels',
#  'the legend of lobo',
#  'in search of the castaways',
#  'son of flubber',
#  'miracle of the white stallions',
#  'savage sam',
#  'summer magic',
#  'the incredible journey',
#  'the sword in the stone',
#  'a tiger walks',
#  'the misadventures of merlin jones',
#  'the three lives of thomasina',
#  'the moon-spinners',
#  'mary poppins',
#  'emil and the detectives',
#  'those calloways',
#  "the monkey's uncle",
#  'that darn cat!',
#  'the ugly dachshund',
#  'lt. robin crusoe, u.s.n.',
#  'the fighting prince of donegal',
#  'follow me, boys!',
#  'monkeys, go home!',
#  'the adventures of bullwhip griffin',
#  'the gnome-mobile',
#  'the jungle book',
#  'charlie, the lonesome cougar',
#  "blackbeard's ghost",
#  'the one and only, genuine, original family band',
#  'never a dull moment',
#  'the horse in the gray flannel suit',
#  'the love bug',
#  'smith!',
#  'rascal',
#  'the computer wore tennis shoes',
#  'king of the grizzlies',
#  'the boatniks',
#  'the wild country',
#  'the aristocats',
#  'the barefoot executive',
#  'scandalous john',
#  'the million dollar duck',
#  'the biscuit eater',
#  "now you see him, now you don't",
#  'napoleon and samantha',
#  'run, cougar, run',
#  'snowball express',
#  "the world's greatest athlete",
#  'charley and the angel',
#  'one little indian',
#  'robin hood',
#  'superdad',
#  'herbie rides again',
#  'the bears and i',
#  'the castaway cowboy',
#  'the island at the top of the world',
#  'the strongest man in the world',
#  'escape to witch mountain',
#  'the apple dumpling gang',
#  'one of our dinosaurs is missing',
#  "the best of walt disney's true-life adventures",
#  'ride a wild pony',
#  'no deposit, no return',
#  'treasure of matecumbe',
#  'gus',
#  'the shaggy d.a.',
#  'freaky friday: the movie',
#  'escape from the dark',
#  'the many adventures of winnie the pooh',
#  'a tale of two critters',
#  'the rescuers',
#  'herbie goes to monte carlo',
#  "pete's dragon",
#  'candleshoe',
#  'return from witch mountain',
#  'the cat from outer space',
#  'hot lead and cold feet',
#  'the north avenue irregulars',
#  'the apple dumpling gang rides again',
#  'unidentified flying oddball',
#  'the black hole',
#  'the omega connection',
#  'midnight madness',
#  'the watcher in the woods',
#  'herbie goes bananas',
#  "the last flight of noah's ark",
#  'popeye',
#  'the devil and max devlin',
#  'amy',
#  'dragonslayer',
#  'the fox and the hound',
#  'condorman',
#  'night crossing',
#  'tron',
#  'tex',
#  'trenchcoat',
#  'something wicked this way comes',
#  'never cry wolf',
#  'return to oz',
#  'the black cauldron',
#  'the journey of natty gann',
#  'one magic christmas',
#  'the great mouse detective',
#  'flight of the navigator',
#  'benji the hunted',
#  'the man from snowy river ii',
#  'oliver & company',
#  'honey, i shrunk the kids',
#  'cheetah',
#  'the little mermaid',
#  'ducktales the movie: treasure of the lost lamp',
#  'the rescuers down under',
#  'white fang',
#  'shipwrecked',
#  "wild hearts can't be broken",
#  'the rocketeer',
#  'beauty and the beast',
#  'newsies',
#  'honey, i blew up the kid',
#  'the mighty ducks',
#  'aladdin',
#  'the muppet christmas carol',
#  'homeward bound: the incredible journey',
#  'a far off place',
#  'the adventures of huck finn',
#  'hocus pocus',
#  'cool runnings',
#  'the three musketeers',
#  'iron will',
#  'blank check',
#  'd2: the mighty ducks',
#  'white fang 2: myth of the white wolf',
#  'the lion king',
#  'angels in the outfield',
#  "squanto: a warrior's tale",
#  'the santa clause',
#  "rudyard kipling's the jungle book",
#  'heavyweights',
#  'man of the house',
#  'tall tale',
#  'a goofy movie',
#  'pocahontas',
#  'operation dumbo drop',
#  "a kid in king arthur's court",
#  'the big green',
#  'frank and ollie',
#  'toy story',
#  'tom and huck',
#  'muppet treasure island',
#  'homeward bound ii:lost in san francisco',
#  'james and the giant peach',
#  'the hunchback of notre dame',
#  'first kid',
#  'd3: the mighty ducks',
#  '101 dalmatians',
#  'that darn cat',
#  'jungle 2 jungle',
#  'hercules',
#  'george of the jungle',
#  'air bud',
#  'rocketman',
#  'flubber',
#  'mr. magoo',
#  'meet the deedles',
#  'mulan',
#  'the parent trap',
#  "i'll be home for christmas",
#  "a bug's life",
#  'mighty joe young',
#  'my favorite martian',
#  "doug's 1st movie",
#  'endurance',
#  'tarzan',
#  'inspector gadget',
#  'the straight story',
#  'toy story 2',
#  'fantasia 2000',
#  'the tigger movie',
#  'dinosaur',
#  'the kid',
#  'remember the titans',
#  '102 dalmatians',
#  "the emperor's new groove",
#  "recess: school's out",
#  'atlantis: the lost empire',
#  'the princess diaries',
#  "max keeble's big move",
#  'monsters, inc.',
#  'snow dogs',
#  'return to never land',
#  'the rookie',
#  'lilo & stitch',
#  'the country bears',
#  'spirited away',
#  'tuck everlasting',
#  'the santa clause 2',
#  'treasure planet',
#  'the jungle book 2',
#  "piglet's big movie",
#  'ghosts of the abyss',
#  'holes',
#  'the lizzie mcguire movie',
#  'finding nemo',
#  'pirates of the caribbean:the curse of the black pearl',
#  'freaky friday',
#  'brother bear',
#  'the haunted mansion',
#  'the young black stallion',
#  "teacher's pet",
#  'miracle',
#  'confessions of a teenagedrama queen',
#  'home on the range',
#  'sacred planet',
#  'around the world in 80 days',
#  "america's heart and soul",
#  'the princess diaries 2:royal engagement',
#  'the incredibles',
#  'national treasure',
#  'aliens of the deep',
#  "pooh's heffalump movie",
#  'the pacifier',
#  'ice princess',
#  'herbie: fully loaded',
#  "howl's moving castle",
#  'sky high',
#  'valiant',
#  'the greatest game ever played',
#  'chicken little',
#  'the chronicles of narnia:the lion, the witch and the wardrobe',
#  'glory road',
#  'roving mars',
#  'eight below',
#  'the shaggy dog',
#  'the wild',
#  'cars',
#  "pirates of the caribbean:  dead man's chest",
#  'invincible',
#  'the nightmare before christmas',
#  'the santa clause 3:the escape clause',
#  'bridge to terabithia',
#  'meet the robinsons',
#  "pirates of the caribbean:  at world's end",
#  'ratatouille',
#  'underdog',
#  'the pixar story',
#  'the game plan',
#  'enchanted',
#  'national treasure: book of secrets',
#  'hannah montana and miley cyrus:best of both worlds concert',
#  'college road trip',
#  'the chronicles of narnia: prince caspian',
#  'wall-e',
#  'beverly hills chihuahua',
#  'morning light',
#  'bolt',
#  'bedtime stories',
#  'the secret of the magic gourd',
#  'race to witch mountain',
#  'hannah montana: the movie',
#  'up',
#  'g-force',
#  'ponyo',
#  'the book of masters',
#  'a christmas carol',
#  'old dogs',
#  'the princess and the frog',
#  'alice in wonderland',
#  'prince of persia: the sands of time',
#  'toy story 3',
#  "the sorcerer's apprentice",
#  'tales from earthsea',
#  'the crimson wing: mystery of the flamingos',
#  'secretariat',
#  'do dooni chaar',
#  'tangled',
#  "the boys: the sherman brothers' story",
#  'tron: legacy',
#  'lilly the witch:the journey to mandolan',
#  'mars needs moms',
#  'zokkomon',
#  'african cats',
#  'prom',
#  'pirates of the caribbean:on stranger tides',
#  'cars 2',
#  'winnie the pooh',
#  'the muppets',
#  'arrietty',
#  'john carter',
#  'chimpanzee',
#  'arjun: the warrior prince',
#  'brave',
#  'the odd life of timothy green',
#  'frankenweenie',
#  'wreck-it ralph',
#  'oz the great and powerful',
#  'wings of life',
#  'monsters university',
#  'the lone ranger',
#  'planes',
#  'frozen',
#  'saving mr. banks',
#  'muppets most wanted',
#  'bears',
#  'million dollar arm',
#  'maleficent',
#  'planes: fire & rescue',
#  'khoobsurat',
#  'alexander and the terrible, horrible, no good, very bad day',
#  'big hero 6',
#  'into the woods',
#  'mcfarland, usa',
#  'cinderella',
#  'monkey kingdom',
#  'tomorrowland',
#  'inside out',
#  'abcd 2',
#  'the good dinosaur',
#  'the finest hours',
#  'zootopia',
#  'the jungle book',
#  'tini: the movie',
#  'alice through the looking glass',
#  'finding dory',
#  'the bfg',
#  "pete's dragon",
#  'queen of katwe',
#  'moana',
#  'dangal',
#  'march of the penguins',
#  'beauty and the beast',
#  'born in china',
#  'pirates of the caribbean:dead men tell no tales',
#  'cars 3',
#  'jagga jasoos',
#  'coco',
#  'a wrinkle in time',
#  'incredibles 2',
#  'christopher robin',
#  'the nutcracker and the four realms',
#  'ralph breaks the internet',
#  'mary poppins returns',
#  'dumbo',
#  'penguins',
#  'aladdin',
#  'toy story 4',
#  'the lion king',
#  'maleficent: mistress of evil',
#  'lady and the tramp',
#  'noelle',
#  'frozen ii',
#  'togo',
#  'timmy failure: mistakes were made',
#  'onward',
#  'stargirl',
#  'dolphin reef',
#  'elephant',
#  'artemis fowl',
#  'hamilton',
#  'black is king',
#  'magic camp',
#  'the one and only ivan',
#  'mulan',
#  'godmothered',
#  'safety',
#  'soul',
#  'flora & ulysses',
#  'raya and the last dragon',
#  'night at the museum']

# %%
# The length of title_runtime_int equals movies_with_runtime_int
len(title_runtime_int)
# Out:
# 428

# %%
# How many unique titles are there?
len({x:title_runtime_int.count(x) for x in title_runtime_int})
# Out:
# 416

# %% [markdown]
# The count of unique movies that have an integer running time is 416.

# %%
# Rename the title_runtime_int list to only store the unique titles in title_runtime_int
title_runtime_int = list({x:title_runtime_int.count(x) for x in title_runtime_int}.keys())
len(title_runtime_int)
# Out:
# 416

# %% [markdown]
# ## Function: running_time(dictionary)

# %%
# Create a function that will take in a dictionary that contains the key 'Running time'.
# If the value type of 'Running time' is a str then change the value to an integer variable 'time'.
# return the 'time' variable
def running_time(dictionary):
    if type(dictionary['Running time']) is str:
        time = int(dictionary['Running time'].split(' ', 1)[0].split('–')[0])
       
    
    elif (type(dictionary['Running time']) is list) and (sum([x.find('minutes') for x in dictionary['Running time']])>0):
        time = [int(x.split(' ', 1)[0].split('–')[0]) for x in dictionary['Running time']][0]
     
    else:
        time =  dictionary['Running time']
            
    return time

# %%
# Testing running_time(dictionary) with 'vanishing praire'
test = df[[index for index, x in enumerate(df) if x['title'] == 'the vanishing prairie'][0]]
test
# Out:
# {'title': 'the vanishing prairie',
#  'Produced by': ['ben sharpsteen', 'walt disney'],
#  'Written by': ['james algar', 'winston hibler'],
#  'Narrated by': 'winston hibler',
#  'Music by': 'paul j. smith',
#  'Cinematography': 'n. paul kenworthy',
#  'Edited by': 'lloyd l. richardson',
#  'Production company': 'walt disney productions',
#  'Distributed by': 'buena vista distribution',
#  'Release date': ['august 17, 1954 ( 1954-08-17 )'],
#  'Running time': ['60 minutes (vhs version)', '71 minutes (original)'],
#  'Country': 'united states',
#  'Language': 'english',
#  'Box office': '$1.75 million (us and canadian rentals)'}

# %%
[int(x.split(' min', 1)[0].split('–')[0]) for x in test['Running time']][0]
# Out:
# 60

# %%
# Testing running_time(dictionary) function.
# Grab the dictionary for 'Savage Sam' and store the dictionary as variable, 'test'.
test = df[[index for index, x in enumerate(df) if x['title']=='savage sam'][0]]
test
# Out:
# {'title': 'savage sam',
#  'Directed by': 'norman tokar',
#  'Produced by': ['ron miller', 'walt disney'],
#  'Written by': ['fred gipson', 'william turberg'],
#  'Based on': 'savage sam by fred gipson',
#  'Starring': ['brian keith', 'tommy kirk', 'kevin corcoran'],
#  'Music by': 'oliver wallace',
#  'Cinematography': 'edward colman',
#  'Edited by': 'grant k. smith',
#  'Production company': 'walt disney productions',
#  'Distributed by': 'buena vista distribution',
#  'Release date': 'june 1, 1963',
#  'Running time': '103 minutes',
#  'Country': 'united states',
#  'Language': 'english',
#  'Box office': '$3,000,000 (us/ canada)'}

# %%
# Testing running_time(dictionary) function with 'test' variable.
running_time(test)
# Out:
# 103

# %%
# How many dictionaries in our list contain a title that is in the list title_runtime_int?
len([x for x in df if x['title'] in title_runtime_int ])
# Out:
# 429

# %% [markdown]
# Question the data - Are there repeating dictionary titles maybe for remakes of movies?

# %%
# update df to change the keys of dictionaries that contain 'Running time' to integers using running_time(dictionary)
# Else - if there is no 'Running time' in the dictionary return the original dictionary

df = [{**x, 'Running time': running_time(x)} if 'Running time' in x else x for x in df ]

# %%
# How many movies do not have running time as an integer?
len([x for x in df if 'Running time' in x and type(x['Running time']) is not int])
# Out:
# 4

# %%
# Which movies do not have 'Running time' as an integer?
[{'title': x['title'], 'Running time': x['Running time']} for x in df if 'Running time' in x and type(x['Running time']) is not int]
# Out:
# [{'title': 'the happiest millionaire',
#   'Running time': ['los angeles', 'new york city', "director's cut"]},
#  {'title': 'high school musical 3:  senior year', 'Running time': ['[1]']},
#  {'title': 'jonas brothers:the 3d concert experience',
#   'Running time': ['[1]', '[2]']},
#  {'title': 'earth', 'Running time': ['[1]']}]

# %%
# Change running time of 'The Happiest Millionarie'
df[[index for index, x in enumerate(df) if x['title']=='the happiest millionaire'][0]]['Running time'] = 118

# %%
# Change running time of 'High School Musical 3:  Senior Year'
df[[index for index, x in enumerate(df) if x['title']=='high school musical 3:  senior year'][0]]['Running time'] = 111

# %%
# Change running time of 'Jonas Brothers: the 3D Concert Experience'
df[[index for index, x in enumerate(df) if x['title']=='jonas brothers:the 3d concert experience'][0]]['Running time'] = 76

# %%
# Change running time of 'Earth'
df[[index for index, x in enumerate(df) if x['title']=='earth'][0]]['Running time'] = 90

# %%
# Check that running time updated
[{'title': x['title'], 'Running time': x['Running time']} for x in df if x['title'] in ['earth', 'jonas brothers:the 3d concert experience', 'high school musical 3:  senior year', 'the happiest millionaire'] ]
# Out:
# [{'title': 'the happiest millionaire', 'Running time': 118},
#  {'title': 'high school musical 3:  senior year', 'Running time': 111},
#  {'title': 'jonas brothers:the 3d concert experience', 'Running time': 76},
#  {'title': 'earth', 'Running time': 90}]

# %%
# Curious - What is the average 'Running time' value
sum([x['Running time'] for x in df if 'Running time' in x and type(x['Running time']) is int])/len([x['Running time'] for x in df if 'Running time' in x and type(x['Running time']) is int])
# Out:
# 97.5816091954023

# %%
# What is the max running time?
max_time = max([x['Running time'] for x in df if 'Running time' in x and type(x['Running time']) is int])
max_time
# Out:
# 306

# %% [markdown]
# ???? 306 minutes seems too long for a movie. Let's find out where this may be later.

# %%
# What is the minimum running time?
min_time = min(x['Running time'] for x in df if 'Running time' in x)
min_time
# Out:
# 22

# %% [markdown]
# This seems too short for a feature length film.
# \
# \
# Let's look at where these minimum and maximums are.

# %%
# find dictionaries where running time is equal to max_time. Store the index, and title in a list.
[(index, x['title']) for index, x in enumerate(df) if ('Running time' in x) and (x['Running time']==max_time) ]
# Out:
# [(446, 'night at the museum')]

# %% [markdown]
# Going back to the wiki page for 'Night at the Museum' This is a movie that is set for future production. This movie is part of a series, and looks like the wiki pages shows running time as running time for all the movies. We can remove this dictionary from the df list.

# %%
# find dictionaries where running time is equal to min_time. Store the index, and title in a list.
[(index, x['title']) for index, x in enumerate(df) if ('Running time' in x) and (x['Running time']==min_time)]
# Out:
# [(43, 'zorro'), (48, 'zorro')]

# %% [markdown]
# Going back to the wiki page for 'Zorro' these are both a part of series that aired on ABC. These are only episodes that are 22 minutes long. We can remove these dictionaries from the df list.

# %%
# Let's make sure there is only one 'Night at the Museum' movie before we remove the dictionary.
[(index, x['title']) for index, x in enumerate(df) if x['title']=='night at the museum']
# Out:
# [(446, 'night at the museum')]

# %%
# Let's make sure there are only two 'Zorro' movies before we remove the dictionaries.
[(index,x['title']) for index, x in enumerate(df) if x['title']=='zorro']
# Out:
# [(43, 'zorro'), (48, 'zorro')]

# %%
# Let's remove these movies from the list.
df = [x for x in df if x['title'] not in ['night at the museum', 'zorro']]

# the length should be 444 if we are dropping 3 movies.    
len(df)
# Out:
# 444

# %%
# Now what is the movie with the max time?
max_time = max([x['Running time'] for x in df if 'Running time' in x and type(x['Running time']) is int])
max_time
# Out:
# 167

# %%
[(index, x) for index, x in enumerate(df) if ('Running time' in x) and (x['Running time']==max_time) ]
# Out:
# [(302,
#   {'title': "pirates of the caribbean:  at world's end",
#    'Directed by': 'gore verbinski',
#    'Produced by': 'jerry bruckheimer',
#    'Written by': ['ted elliott', 'terry rossio'],
#    'Based on': ['characters by ted elliott terry rossio stuart beattie jay wolpert',
#     'ted elliott',
#     'terry rossio',
#     'stuart beattie',
#     'jay wolpert',
#     'pirates of the caribbean by walt disney'],
#    'Starring': ['johnny depp',
#     'orlando bloom',
#     'keira knightley',
#     'stellan skarsgård',
#     'bill nighy',
#     'chow yun-fat',
#     'geoffrey rush',
#     'jack davenport',
#     'kevin r. mcnally',
#     'jonathan pryce'],
#    'Music by': 'hans zimmer',
#    'Cinematography': 'dariusz wolski',
#    'Edited by': ['craig wood', 'stephen rivkin'],
#    'Production companies': ['walt disney pictures', 'jerry bruckheimer films'],
#    'Distributed by': 'buena vista pictures',
#    'Release date': ['may 19, 2007 ( 2007-05-19 ) ( disneyland resort )',
#     'may 25, 2007 ( 2007-05-25 ) (united states)'],
#    'Running time': 167,
#    'Country': 'united states',
#    'Language': 'english',
#    'Budget': '$300 million',
#    'Box office': '$961 million'})]

# %%
# Now what is the movie with the min time?
min_time = min(x['Running time'] for x in df if 'Running time' in x)
min_time
# Out:
# 40

# %%
[(index, x) for index, x in enumerate(df) if ('Running time' in x) and (x['Running time']==min_time)]
# Out:
# [(273,
#   {'title': 'sacred planet',
#    'Directed by': ['jon long', 'hairul salleh askor'],
#    'Produced by': ['jon long', 'karen fernandez long'],
#    'Written by': ['karen fernandez long', 'jon long'],
#    'Starring': ['arapata mckay',
#     'tsaan ciqae',
#     'mae tui',
#     'cy peck jr.',
#     'mutang urud'],
#    'Narrated by': 'robert redford',
#    'Cinematography': 'william reeve',
#    'Edited by': 'jon long',
#    'Production company': 'walt disney pictures',
#    'Distributed by': 'buena vista pictures',
#    'Release date': ['april 22, 2004 ( 2004-04-22 )'],
#    'Running time': 40,
#    'Countries': ['canada', 'malaysia', 'united states'],
#    'Language': 'english',
#    'Box office': '$1,108,356'}),
#  (291,
#   {'title': 'roving mars',
#    'Directed by': 'george butler',
#    'Produced by': ['frank marshall'],
#    'Written by': ['robert andrus', 'george butler'],
#    'Narrated by': 'paul newman (introduction only)',
#    'Music by': ['philip glass', 'sigur rós'],
#    'Cinematography': 't.c. christensen',
#    'Edited by': 'nancy baker',
#    'Production companies': ['walt disney pictures',
#     'white mountain films',
#     'the kennedy/marshall company'],
#    'Distributed by': 'buena vista pictures',
#    'Release date': ['january 27, 2006 ( 2006-01-27 )'],
#    'Running time': 40,
#    'Country': 'united states',
#    'Language': 'english',
#    'Budget': '$1 million',
#    'Box office': '$11 million'})]

# %%
# We now have the Running time field cleaned up.
# let's save this to a 'cleaned' version - movie_dictionaries_cleaned.json

write_to_json(df,'movie_dictionaries_cleaned.json')

# %%
df=load_data('movie_dictionaries_cleaned.json')
len(df)
# Out:
# 444

# %%
[(index, x['title']) for index,x in enumerate(df) if x.get('Running time', 'N\A')=='N\A']
# Out:
# [(324, 'lilly the witch:the dragon and the magic book'),
#  (327, 'walt & el grupo'),
#  (344, 'anaganaga o dheerudu'),
#  (401, 'ghost of the mountains'),
#  (436, 'cruella'),
#  (437, 'jungle cruise'),
#  (438, 'the beatles: get back'),
#  (439, 'encanto'),
#  (440, 'the little mermaid'),
#  (441, 'peter pan & wendy'),
#  (442, 'home alone'),
#  (443, 'shrunk')]

# %% [markdown]
# Looking at the wiki pages for these movies the running time is either not listed or the movie is 'in production' phase

# %% [markdown]
# # Cleaning task - Standardize budget and box office fields to be float data type.

# %%
# movie has 'Budget' data
len([x.get('Budget') for x in df if x.get('Budget') is not None])
# Out:
# 284

# %%
# movie has 'Box office' data
len([x.get('Box office') for x in df if x.get('Box office') is not None])
# Out:
# 368

# %%
# movie has both 'Box office' and 'Budget data'
len([(x.get('Budget'), x.get('Box office')) for x in df if x.get('Budget') is not None and x.get('Box office') is not None])
# Out:
# 272

# %%
# what does the format of the budget key look like?
[(i,x.get('Budget')) for i,x in enumerate(df) if x.get('Budget') is not None]
# Out:
# [(1, '$1.49 million'),
#  (2, '$2.6 million'),
#  (3, '$2.28 million'),
#  (4, '$600,000'),
#  (5, '$950,000'),
#  (6, '$858,000'),
#  (8, '$788,000'),
#  (10, '$1.35 million'),
#  (11, '$2.125 million'),
#  (13, '$1.5 million'),
#  (14, '$1.5 million'),
#  (16, '$2.9 million'),
#  (17, '$1,800,000'),
#  (18, '$3 million'),
#  (20, '$4 million'),
#  (21, '$2 million'),
#  (22, '$300,000'),
#  (23, '$1.8 million'),
#  (25, '$5 million'),
#  (27, '$4 million'),
#  (34, '$700,000'),
#  (40, '$6 million'),
#  (41, 'under $1 million or $1,250,000'),
#  (43, '$2 million'),
#  (46, '$2.5 million'),
#  (49, '$4 million'),
#  (50, '$3.6 million'),
#  (55, '$3 million'),
#  (57, '$3 million'),
#  (67, '$3 million'),
#  (72, '$4.4–6 million'),
#  (84, '$4 million'),
#  (86, '$5 million'),
#  (91, '$5 million'),
#  (98, '$4 million'),
#  (102, '$6.3 million'),
#  (111, '$5 million'),
#  (116, '$8 million'),
#  (122, 'au$1 million'),
#  (399, '$230–320 million'),
#  (400, '$175 million'),
#  (402, ['[2]']),
#  (403, '$175–225 million'),
#  (404, '$100–130 million'),
#  (405, '$200 million'),
#  (406, '$70-75 million'),
#  (407, '$120–133 million'),
#  (408, '$175 million'),
#  (409, '$130 million'),
#  (410, '$170 million'),
#  (412, '$183 million'),
#  (413, '$200 million'),
#  (414, '$250–260 million'),
#  (415, '$185 million'),
#  (416, '$60 million'),
#  (418, '$150 million'),
#  (419, '$40 million'),
#  (420, '$42 million'),
#  (421, '$175–200 million'),
#  (425, '$125 million'),
#  (426, '$12.5 million (stage production)'),
#  (428, '$24 million'),
#  (430, '$200 million'),
#  (433, '$150 million+')]

# %% [markdown]
# - Let's strip out `$` - strip('$')
# - Let's strip out 'million' and the space before it so we don't have to strip the space later - .strip(' million')
# - For the movies that are in hundred thousands replace ',' with '' - .replace(',',"")

# %%
budget_int_list = []
could_not_convert = []
for i,x in enumerate(df):
    if x.get('Budget') is not None and type(x.get('Budget')) is str:
        try:
            budget = float(x.get('Budget').strip('$').split(' million', 1)[0].replace(',',"").split('–',1)[0].split('-')[0].split('to',1)[0])
            
            
            if budget < 500.0:
                budget =budget * (1000000)
            
            budget_int_list.append(budget)
            df[i]['Budget']=budget
            print(i,budget)
        
        except Exception as e:
            could_not_convert.append({i:{'title':x.get('title'),'Budget':x.get('Budget')}})
            print(e, i, x.get('title'), x.get('Budget'))
            continue
            
    elif x.get('Budget') is not None and type(x.get('Budget')) is list:
        try:
            budget=float(x.get('Budget')[0].strip('$').split(' million', 1)[0].replace(',',"").split('–',1)[0].split('-')[0].split('to',1)[0])
            
            if budget < 500.0:
                budget =budget * (1000000)
            
            budget_int_list.append(budget)
            df[i]['Budget']=budget
            print(i,budget)
        
        except Exception as e:
            could_not_convert.append({i:{'title':x.get('title'),'Budget':x.get('Budget')}})
            print(e, i, x.get('title'), x.get('Budget'))
            continue
# Out:
# 1 1490000.0
# 2 2600000.0
# 3 2280000.0
# 4 600000.0
# 5 950000.0
# 6 858000.0
# 8 788000.0
# 10 1350000.0
# 11 2125000.0
# 13 1500000.0
# 14 1500000.0
# 16 2900000.0
# 17 1800000.0
# 18 3000000.0
# 20 4000000.0
# 21 2000000.0
# 22 300000.0
# 23 1800000.0
# 25 5000000.0
# 27 4000000.0
# 34 700000.0
# 40 6000000.0
# could not convert string to float: 'under $1' 41 the shaggy dog under $1 million or $1,250,000
# 43 2000000.0
# 46 2500000.0
# 49 4000000.0
# 50 3600000.0
# 55 3000000.0
# 57 3000000.0
# 67 3000000.0
# 72 4400000.0
# 84 4000000.0
# 86 5000000.0
# 91 5000000.0
# 98 4000000.0
# 102 6300000.0
# 111 5000000.0
# 116 8000000.0
# could not convert string to float: 'au$1' 122 ride a wild pony au$1 million
# 127 5000000.0
# 131 7500000.0
# 133 10000000.0
# 136 3500000.0
# 140 5250000.0
# 141 20000000.0
# 144 9000000.0
# 146 6000000.0
# 147 20000000.0
# 150 18000000.0
# 151 12000000.0
# 152 14000000.0
# 325 150000000.0
# could not convert string to float: '¥' 326 ponyo ['¥', 'us$']
# 328 8000000.0
# 329 175000000.0
# 330 35000000.0
# 331 105000000.0
# 332 150000000.0
# 333 80000000.0
# 334 200000000.0
# 335 200000000.0
# 336 150000000.0
# 337 22000000.0
# 339 35000000.0
# 341 260000000.0
# 343 170000000.0
# could not convert string to float: '₹ 27 crore (us$3.8' 344 anaganaga o dheerudu ₹ 27 crore (us$3.8 million)
# 346 150000000.0
# 348 5000000.0
# 349 8000000.0
# 350 410600000.0
# 351 200000000.0
# 352 30000000.0
# 353 45000000.0
# 354 23000000.0
# 355 306600000.0
# 356 5000000.0
# 358 185000000.0
# 359 25000000.0
# 360 39000000.0
# 361 165000000.0
# 362 200000000.0
# 364 200000000.0
# 365 225000000.0
# 366 50000000.0
# 367 150000000.0
# 368 35000000.0
# 369 51000000.0
# 370 5000000.0
# 371 25000000.0
# 372 180000000.0
# 373 50000000.0
# could not convert string to float: '₹ 230' 374 khoobsurat ₹ 230 million (us$3.2 million)
# 375 28000000.0
# 376 165000000.0
# 377 50000000.0
# 378 25000000.0
# 379 95000000.0
# 380 5000000.0
# 381 180000000.0
# 382 175000000.0
# could not convert string to float: '₹520' 383 abcd 2 ₹520 million
# 384 175000000.0
# 385 70000000.0
# 386 150000000.0
# 387 175000000.0
# 389 170000000.0
# 390 175000000.0
# 391 140000000.0
# 392 65000000.0
# 393 15000000.0
# 394 150000000.0
# could not convert string to float: '₹ 70 crore' 395 dangal ₹ 70 crore
# 396 8000000.0
# 397 160000000.0
# 398 5000000.0
# 399 230000000.0
# 400 175000000.0
# could not convert string to float: '[2]' 402 jagga jasoos ['[2]']
# 403 175000000.0
# 404 100000000.0
# 405 200000000.0
# 406 70000000.0
# 407 120000000.0
# 408 175000000.0
# 409 130000000.0
# 410 170000000.0
# 412 183000000.0
# 413 200000000.0
# 414 250000000.0
# 415 185000000.0
# 416 60000000.0
# 418 150000000.0
# 419 40000000.0
# 420 42000000.0
# 421 175000000.0
# 425 125000000.0
# 426 12500000.0
# 428 24000000.0
# 430 200000000.0
# 433 150000000.0

# %%
budget_int_list.sort()
budget_int_list
# Out:
# [300000.0,
#  600000.0,
#  700000.0,
#  788000.0,
#  858000.0,
#  950000.0,
#  1000000.0,
#  1350000.0,
#  1490000.0,
#  1500000.0,
#  1500000.0,
#  1800000.0,
#  1800000.0,
#  2000000.0,
#  2000000.0,
#  2125000.0,
#  2280000.0,
#  2500000.0,
#  2600000.0,
#  2900000.0,
#  3000000.0,
#  3000000.0,
#  3000000.0,
#  3000000.0,
#  3000000.0,
#  3500000.0,
#  3600000.0,
#  4000000.0,
#  4000000.0,
#  4000000.0,
#  4000000.0,
#  4000000.0,
#  4400000.0,
#  5000000.0,
#  5000000.0,
#  5000000.0,
#  5000000.0,
#  5000000.0,
#  5000000.0,
#  5000000.0,
#  5000000.0,
#  5000000.0,
#  5000000.0,
#  5000000.0,
#  5000000.0,
#  5000000.0,
#  5250000.0,
#  6000000.0,
#  6000000.0,
#  6300000.0,
#  6500000.0,
#  7000000.0,
#  7500000.0,
#  8000000.0,
#  8000000.0,
#  8000000.0,
#  8000000.0,
#  9000000.0,
#  9000000.0,
#  10000000.0,
#  10000000.0,
#  10000000.0,
#  11000000.0,
#  11000000.0,
#  12000000.0,
#  12000000.0,
#  12000000.0,
#  12000000.0,
#  12500000.0,
#  13000000.0,
#  13000000.0,
#  14000000.0,
#  14000000.0,
#  14000000.0,
#  14000000.0,
#  15000000.0,
#  15000000.0,
#  15000000.0,
#  15000000.0,
#  15000000.0,
#  15000000.0,
#  15000000.0,
#  15000000.0,
#  16000000.0,
#  17000000.0,
#  17000000.0,
#  18000000.0,
#  18000000.0,
#  20000000.0,
#  20000000.0,
#  20000000.0,
#  20000000.0,
#  20000000.0,
#  20000000.0,
#  20000000.0,
#  20000000.0,
#  20000000.0,
#  20000000.0,
#  22000000.0,
#  22000000.0,
#  22000000.0,
#  22000000.0,
#  22000000.0,
#  23000000.0,
#  23000000.0,
#  24000000.0,
#  24000000.0,
#  24000000.0,
#  25000000.0,
#  25000000.0,
#  25000000.0,
#  25000000.0,
#  25000000.0,
#  25000000.0,
#  25000000.0,
#  25000000.0,
#  25000000.0,
#  26000000.0,
#  26000000.0,
#  26000000.0,
#  28000000.0,
#  28000000.0,
#  28000000.0,
#  28000000.0,
#  28000000.0,
#  30000000.0,
#  30000000.0,
#  30000000.0,
#  30000000.0,
#  30000000.0,
#  30000000.0,
#  30000000.0,
#  30000000.0,
#  30000000.0,
#  30000000.0,
#  31000000.0,
#  31000000.0,
#  31000000.0,
#  32000000.0,
#  32000000.0,
#  33000000.0,
#  35000000.0,
#  35000000.0,
#  35000000.0,
#  35000000.0,
#  35000000.0,
#  35000000.0,
#  35000000.0,
#  38000000.0,
#  39000000.0,
#  40000000.0,
#  40000000.0,
#  40000000.0,
#  40000000.0,
#  42000000.0,
#  44000000.0,
#  45000000.0,
#  45000000.0,
#  45000000.0,
#  46000000.0,
#  46000000.0,
#  47000000.0,
#  50000000.0,
#  50000000.0,
#  50000000.0,
#  50000000.0,
#  50000000.0,
#  50000000.0,
#  51000000.0,
#  55000000.0,
#  55000000.0,
#  56000000.0,
#  60000000.0,
#  60000000.0,
#  65000000.0,
#  65000000.0,
#  65000000.0,
#  65000000.0,
#  70000000.0,
#  70000000.0,
#  75000000.0,
#  80000000.0,
#  80000000.0,
#  80000000.0,
#  80000000.0,
#  80000000.0,
#  80000000.0,
#  85000000.0,
#  85000000.0,
#  85000000.0,
#  90000000.0,
#  90000000.0,
#  90000000.0,
#  90000000.0,
#  90000000.0,
#  90000000.0,
#  92000000.0,
#  94000000.0,
#  95000000.0,
#  100000000.0,
#  100000000.0,
#  100000000.0,
#  100000000.0,
#  105000000.0,
#  110000000.0,
#  110000000.0,
#  115000000.0,
#  120000000.0,
#  120000000.0,
#  120000000.0,
#  125000000.0,
#  127500000.0,
#  130000000.0,
#  130000000.0,
#  130000000.0,
#  140000000.0,
#  140000000.0,
#  140000000.0,
#  150000000.0,
#  150000000.0,
#  150000000.0,
#  150000000.0,
#  150000000.0,
#  150000000.0,
#  150000000.0,
#  150000000.0,
#  150000000.0,
#  150000000.0,
#  150000000.0,
#  150000000.0,
#  150000000.0,
#  160000000.0,
#  165000000.0,
#  165000000.0,
#  170000000.0,
#  170000000.0,
#  170000000.0,
#  175000000.0,
#  175000000.0,
#  175000000.0,
#  175000000.0,
#  175000000.0,
#  175000000.0,
#  175000000.0,
#  175000000.0,
#  175000000.0,
#  175000000.0,
#  180000000.0,
#  180000000.0,
#  180000000.0,
#  180000000.0,
#  183000000.0,
#  185000000.0,
#  185000000.0,
#  200000000.0,
#  200000000.0,
#  200000000.0,
#  200000000.0,
#  200000000.0,
#  200000000.0,
#  200000000.0,
#  200000000.0,
#  225000000.0,
#  225000000.0,
#  225000000.0,
#  230000000.0,
#  250000000.0,
#  260000000.0,
#  300000000.0,
#  306600000.0,
#  410600000.0]

# %%
len(could_not_convert)
# Out:
# 13

# %%
could_not_convert
# Out:
# [{41: {'title': 'the shaggy dog', 'Budget': 'under $1 million or $1,250,000'}},
#  {122: {'title': 'ride a wild pony', 'Budget': 'au$1 million'}},
#  {154: {'title': 'tron', 'Budget': 'us$ 17 million'}},
#  {156: {'title': 'trenchcoat', 'Budget': 'unknown'}},
#  {166: {'title': 'the man from snowy river ii', 'Budget': 'a$8.7 million'}},
#  {254: {'title': 'spirited away', 'Budget': ['¥', '[2]', '[3]', '[4]']}},
#  {284: {'title': "howl's moving castle", 'Budget': ['¥']}},
#  {326: {'title': 'ponyo', 'Budget': ['¥', 'us$']}},
#  {344: {'title': 'anaganaga o dheerudu',
#    'Budget': '₹ 27 crore (us$3.8 million)'}},
#  {374: {'title': 'khoobsurat', 'Budget': '₹ 230 million (us$3.2 million)'}},
#  {383: {'title': 'abcd 2', 'Budget': '₹520 million'}},
#  {395: {'title': 'dangal', 'Budget': '₹ 70 crore'}},
#  {402: {'title': 'jagga jasoos', 'Budget': ['[2]']}}]

# %%
[{i:{x.get('title'): x.get('Budget')}} for i,x in enumerate(df) if type(x.get('Budget')) is not float and x.get('Budget') is not None]
# Out:
# [{41: {'the shaggy dog': 'under $1 million or $1,250,000'}},
#  {122: {'ride a wild pony': 'au$1 million'}},
#  {154: {'tron': 'us$ 17 million'}},
#  {156: {'trenchcoat': 'unknown'}},
#  {166: {'the man from snowy river ii': 'a$8.7 million'}},
#  {254: {'spirited away': ['¥', '[2]', '[3]', '[4]']}},
#  {284: {"howl's moving castle": ['¥']}},
#  {326: {'ponyo': ['¥', 'us$']}},
#  {344: {'anaganaga o dheerudu': '₹ 27 crore (us$3.8 million)'}},
#  {374: {'khoobsurat': '₹ 230 million (us$3.2 million)'}},
#  {383: {'abcd 2': '₹520 million'}},
#  {395: {'dangal': '₹ 70 crore'}},
#  {402: {'jagga jasoos': ['[2]']}}]

# %% [markdown]
# We will go ahead manually manipulate these budgets based on their wiki pages. If there is an austrailian (au) currency we will default to us currency.

# %%
df[41]['Budget'] = 1250000.0
df[122]['Budget'] = 1000000.0
df[154]['Budget'] = 17000000.0
df[156]['Budget'] = 'NA'
df[166]['Budget'] = 8700000.0
df[254]['Budget'] = 15000000.0
df[284]['Budget'] = 24000000.0
df[326]['Budget'] = 34000000.0
df[344]['Budget'] = 3800000.0
df[374]['Budget'] = 3200000.0
df[383]['Budget'] = 'NA'
df[395]['Budget'] = 'NA'
df[402]['Budget'] = 'NA'

# %%
# how many movies have a budget value that is now a float?
len([x for x in df if type(x.get('Budget')) is float])
# Out:
# 280

# %% [markdown]
# This makes sense because we manipulated 4 movies to have a value of 'NA' that did not have a budget value of float.

# %%
# How many movies have a Budget key?
len([x for x in df if x.get('Budget') is not None])
# Out:
# 284

# %% [markdown]
# This makes sense because this is the total amount of movies that have a budget type of float, and includes the movies that have Budget as 'NA' that we manipulated.

# %%
# How many movies DO NOT have a budget key?
len([x for x in df if x.get('Budget') is None])
# Out:
# 160

# %% [markdown]
# There are 284 movies that have a budget key and 160 that do not. This totals 444 movies that is the total amount in df. :)

# %% [markdown]
# Now let's look at cleanning up the box office field.

# %%
# How is the box office field formatted?
[x['Box office'] for x in df if x.get('Box office') is not None]
# Out:
# ['$45.472',
#  '$418 million',
#  '$164 million',
#  '$76.4–$83.3 million',
#  '$960,000 (worldwide rentals)',
#  '$1.3 million (est. united states/canada rentals, 1941)',
#  '$267.4 million',
#  '$1,135,000 (worldwide rentals)',
#  '$799,000',
#  '$3,355,000 (worldwide rentals)',
#  '$3.275 million (worldwide rentals)',
#  '$65 million',
#  '$3,165,000 (worldwide rentals)',
#  '$2,560,000 (worldwide rentals)',
#  '$3.7 million (u.s. rental) $575,000 (foreign rental)',
#  '$1,625,000 (worldwide rentals)',
#  '$263.6 million',
#  '$4,100,000 (worldwide rentals)',
#  '$5.6 million (us, 1951)',
#  '$2.1 million (us rentals)',
#  '$87.4 million',
#  '$1 million (us)',
#  '$2.6 million (us)',
#  '$1.75 million (us and canadian rentals)',
#  '$28.2 million',
#  '$2,150,000 (us)',
#  '$187 million',
#  '$2.1 million (us)',
#  '$1.6 million (us)',
#  '$1.7 million (us)',
#  '$2.75 million (us)',
#  '$1.75 million (us rentals)',
#  '$6,250,000 (us/canada rentals)',
#  '$1.8 million (est. us/ canada rentals)',
#  '$2.5 million (est. us/ canada rentals)',
#  '$51.6 million (united states/canada)',
#  '$12.3 million (us and canada rentals)',
#  ['[2]', '[3]'],
#  '$1,700,000 (us/canada rentals)',
#  '$3,100,000 (us/canada rentals)',
#  '$3.75 million (us and canadian rentals)',
#  '$2.3 million (us and canadian rentals)',
#  '$40 million',
#  '$303 million',
#  '$25.4 million',
#  '$25.1 million',
#  '$4.6 million (u.s./canada rentals)',
#  '$3.5 million',
#  '$5 million (rentals)',
#  '$21,745,500',
#  '$22.1 million',
#  '$2,550,000 (us/ canada)',
#  '$3,000,000 (us/ canada)',
#  '$4,350,000 (us/ canada rentals)',
#  '$4.2 million (us/canada) (rentals)',
#  '$22.2 million',
#  'est. $1,600,000 (us/ canada)',
#  '$4,000,000 (us/ canada)',
#  '$2,250,000 (us/ canada)',
#  'est. $3,500,000 (us/ canada)',
#  '$103.1 million',
#  '$1,275,000',
#  '$3,500,000 (us/ canada rentals)',
#  '$4,000,000 (us/canada rentals)',
#  '$28,068,222',
#  '$6.2 million (est. us/ canada rentals)',
#  '$22,565,634',
#  '$16,207,116',
#  '$3,000,000 (us/ canada)',
#  '$1,900,000 (us/ canada)',
#  '$4,000,000 (us/ canada)',
#  '$378 million',
#  '$5 million (u.s./canada rentals)',
#  '$21,540,050',
#  '$2,250,000 (us/ canada)',
#  '$4,150,000 (us/ canada rentals)',
#  '$3.3 million  (us/ canada rentals)',
#  '$51,264,000',
#  '$1.3 million (us/ canada rentals)',
#  '$5.5 million (us/ canada rentals)',
#  '$18,607,492',
#  '$4 million (rentals) (us/canada)',
#  '$191 million',
#  '$5.1 million (north america) (rentals)',
#  '$17.9 million',
#  '$4,610,000 (us/canada) (rentals)',
#  '$6,100,000 (us/ canada rentals)',
#  '$22,583,370',
#  '$2 million',
#  '$32 million',
#  '$7 million (us/canada rentals)',
#  ['[1]'],
#  '$4 million (rentals) (us/canada)',
#  '$10 million (us/canada rentals)',
#  '$6.6 million (us/canada rentals)',
#  '$20,000,000',
#  '$36,853,000',
#  '$5.5 million (north american rentals)',
#  '$21,873,000',
#  '$10.5 million (us and canada rentals)',
#  '$36 million',
#  '$169 million',
#  '$29 million',
#  '$36 –39.6 million',
#  '$20,931,111',
#  ['[1]'],
#  '$2.9 million',
#  '$5 million',
#  '$18 million',
#  '$11 million',
#  '$60 million',
#  '$16 million (usa)',
#  '$14.1 million',
#  '$63.5 million',
#  '$8 million',
#  'us$50 million',
#  '$7.4 million',
#  '$4,304,286 (us)',
#  '$8.4 million',
#  '$27.6 million',
#  '$11.1 million (usa)',
#  '$21.3 million',
#  '$9.7 million (u.s. and canada only)',
#  '$13 million',
#  '$38.7 million',
#  '$18,564,613',
#  '$22.3 million',
#  '$13,687,027',
#  '>$121 million',
#  '$222.7 million',
#  '$8,153,677 (united states)',
#  '$233 million',
#  '$18.1 million',
#  '$47.4 million',
#  '$34.8 million',
#  '$15.1 million',
#  '$7.3 million',
#  '$46.7 million (usa)',
#  '$440.1 million',
#  '$2.8 million',
#  '$96 million',
#  '$50.8 million',
#  '$504.1 million',
#  '$27.2 million',
#  '$57 million',
#  '$12.9 million',
#  '$24.1 million',
#  '$44.9 million',
#  '$154.9 million',
#  '$53.9 million',
#  '$21 million',
#  '$39 million',
#  '$45.6 million',
#  '$8,878,839 (us)',
#  '$968.5 million',
#  '$50.2 million',
#  '$3,337,685',
#  '$189.8 million',
#  '$43.2 million',
#  '$17.6 million',
#  '$40,070,995',
#  '$11 million',
#  '$37.6 million',
#  '$346.1 million',
#  '$24,670,346',
#  '$13.4 million (domestic)',
#  '$17.7 million',
#  '$373 million',
#  '$23.9 million',
#  '$34.3 million (north america)',
#  '$32.7 million',
#  '$37.7 million',
#  '$325.3 million',
#  '$26,491,793',
#  '$22.9 million',
#  '$320.7 million',
#  '$18.3 million',
#  '$59.9 million',
#  '$252.7 million',
#  '$174.4 million',
#  '$27.8 million',
#  '$15.4 million',
#  '$178 million',
#  '$28.9 million',
#  '$4.4 million',
#  '$304.3 million',
#  '$92.1 million',
#  '$12.2 million',
#  '$363.3 million',
#  '$50.6 million (us)',
#  '$36.8 million',
#  '$19.4 million',
#  '$448.2 million',
#  '$134.4 million',
#  '$6.2 million (north america)',
#  '$497.4 million',
#  '$90.9 million',
#  '$96.2 million',
#  '$349.8 million',
#  '$110.3 million',
#  '$136.7 million',
#  '$183.6 million',
#  '$169.6 million',
#  '$44.5 million',
#  '$186.1 million',
#  '$165.3 million',
#  '$18.6 million',
#  '$577.4 million',
#  '$115 million',
#  '$115.1 million',
#  '$80.7 million',
#  '$273.1 million',
#  '$18 million',
#  '$395.5 million',
#  '$19.3 million',
#  '$172.9 million',
#  '$109.6 million',
#  '$135.7 million',
#  '$62.9 million',
#  '$28.7 million',
#  '$71.4 million',
#  '$55.5 million',
#  '$940.3 million',
#  '$654.3 million',
#  '$160.8 million',
#  '$250.4 million',
#  '$182.3 million',
#  '$9,638,389',
#  '$6.5 million',
#  '$64.5 million',
#  '$33.1 million',
#  '$145.5 million',
#  '$1,108,356',
#  '$72.2 million',
#  '$314,402',
#  '$134.7 million',
#  '$633 million',
#  '$347.5 million',
#  '$9 million',
#  '$52.9 million',
#  '$198.6 million',
#  '$27.6 million',
#  '$144.1 million',
#  ['¥', '[3]'],
#  '$86.4 million',
#  '$61.7 million',
#  '$15.4 million',
#  '$314.4 million',
#  '$745 million',
#  '$42.9 million',
#  '$11 million',
#  '$120.5 million',
#  '$87.1 million',
#  '$102.3 million',
#  '$462 million',
#  '$1.066 billion',
#  '$58.5 million',
#  '$91.5 million',
#  '$110.8 million',
#  '$137.6 million',
#  '$169.3 million',
#  '$961 million',
#  '$620.7 million',
#  '$65.3 million',
#  '$146.6 million',
#  '$340.5 million',
#  '$459.2 million',
#  '$70.6 million',
#  '$51.5 million',
#  '$419.7 million',
#  '$521.3 million',
#  '$149.3 million',
#  '$275,776',
#  '$252.9 million',
#  '$310 million',
#  '$212.9 million',
#  '$23.1 million',
#  '$106.4 million',
#  '$170  million',
#  '$109 million',
#  '$735.1 million',
#  '$292.8 million',
#  'us$ 203.2 million',
#  '$11.3 million',
#  '$325 million',
#  '$96.8 million',
#  '$270 million',
#  '$1.025 billion',
#  '$82.7 million',
#  '$336.4 million',
#  '$1.067 billion',
#  '$215.3 million',
#  '$75.5 million',
#  '$60.3 million',
#  '$592.4 million',
#  '$55,513',
#  '$400.1 million',
#  '₹ 50 crore (us$7.0 million)',
#  '$39.2 million',
#  '$30.9 million',
#  '$10.7 million',
#  '$1.046 billion',
#  '$562.1 million',
#  '$50.1 million',
#  '$165.2 million',
#  '$146 million',
#  '$284.1 million',
#  '$34.8 million',
#  '$540.4 million',
#  '$56 million',
#  '$81.5 million',
#  '$471.2 million',
#  '$493.3 million',
#  '$743.6 million',
#  '$260.5 million',
#  '$239.3 million',
#  '$1.280 billion',
#  '$117.9 million',
#  '$80.4 million',
#  '$21.3 million',
#  '$39.2 million',
#  '$758.5 million',
#  '$147 million',
#  'est. ₹ 79.43 crore (us$11 million)',
#  '$100.7 million',
#  '$657.8 million',
#  '$213.1 million',
#  '$45.7 million',
#  '$543 million',
#  '$17.1 million',
#  '$209 million',
#  '$858 million',
#  'est. ₹1.65 billion',
#  '$332.2 million',
#  '$52.1 million',
#  '$1.024 billion',
#  '$966.6 million',
#  '$17 million',
#  '$299.5 million',
#  '$1.029 billion',
#  '$195.2 million',
#  '$143.7 million',
#  '$10.4 million',
#  '$690.8 million',
#  ['[4]', '[5]', '[6]', '[7]', '[8]'],
#  '$127.4 million',
#  '$1.264 billion',
#  '$25.1 million',
#  '$794.9 million',
#  '$383.9 million',
#  '₹ 833.5 million',
#  '$807.8 million',
#  '$133.4 million',
#  '$1.243 billion',
#  '$197.7 million',
#  '$174 million',
#  '$529.3 million',
#  '$349.5 million',
#  '$353.3 million',
#  '$7.7\n million',
#  '$1.051 billion',
#  '$1.073 billion',
#  '$1.657 billion',
#  '$491.7 million',
#  '$1.450 billion',
#  '$141.9 million',
#  '$70 million',
#  '$115.7 million']

# %%
# # Looks like we can work this similar to before.

# boxoffice_int_list = []
# could_not_convert = []
# for i,x in enumerate(df):
#     if x.get('Box office') is not None and type(x.get('Box office')) is str:
#         try:
#             boxoffice = float(x.get('Box office').split(' million', 1)[0].split('(worldwide rentals)',1)[0].strip('$').replace(',',"").split('–$',1)[0])
            
            
#             if boxoffice < 1000.0:
#                 boxoffice =boxoffice * (1000000)
            
#             boxoffice_int_list.append((boxoffice,x.get('Box office')))
# #           df[i]['Box office']=boxoffice
#             print(i,boxoffice)
        
#         except Exception as e:
#             could_not_convert.append({i:{'title':x.get('title'),'Box office':x.get('Box office')}})
#             print(e, i, x.get('title'), x.get('Box office'))
#             continue
    
            
#     elif x.get('Box office') is not None and type(x.get('Box office')) is list:
#         try:
#             boxoffice=float(x.get('Box office')[0].split(' million',1)[0].split('(worldwide rentals)',1)[0].strip('$').replace(',',"").split('–$',1)[0])
            
#             if boxoffice < 1000.0:
#                 boxoffice = boxoffice * (1000000)
            
#             boxoffice_int_list.append((boxoffice,x.get('Box office')))
# #             df[i]['Box office']=boxoffice
#             print(i,budget)
        
#         except Exception as e:
#             could_not_convert.append({i:{'title':x.get('title'),'Box office':x.get('Box office')}})
#             print(e, i, x.get('title'), x.get('Box office'))
#             continue

# %%
# boxoffice_int_list.sort()
# boxoffice_int_list

# %% [markdown]
# #### Try using regex compiler

# %%
box_office_values = [x.get('Box office') for i,x in enumerate(df) if type(x.get('Box office')) is str]
box_office_values
# Out:
# ['$45.472',
#  '$418 million',
#  '$164 million',
#  '$76.4–$83.3 million',
#  '$960,000 (worldwide rentals)',
#  '$1.3 million (est. united states/canada rentals, 1941)',
#  '$267.4 million',
#  '$1,135,000 (worldwide rentals)',
#  '$799,000',
#  '$3,355,000 (worldwide rentals)',
#  '$3.275 million (worldwide rentals)',
#  '$65 million',
#  '$3,165,000 (worldwide rentals)',
#  '$2,560,000 (worldwide rentals)',
#  '$3.7 million (u.s. rental) $575,000 (foreign rental)',
#  '$1,625,000 (worldwide rentals)',
#  '$263.6 million',
#  '$4,100,000 (worldwide rentals)',
#  '$5.6 million (us, 1951)',
#  '$2.1 million (us rentals)',
#  '$87.4 million',
#  '$1 million (us)',
#  '$2.6 million (us)',
#  '$1.75 million (us and canadian rentals)',
#  '$28.2 million',
#  '$2,150,000 (us)',
#  '$187 million',
#  '$2.1 million (us)',
#  '$1.6 million (us)',
#  '$1.7 million (us)',
#  '$2.75 million (us)',
#  '$1.75 million (us rentals)',
#  '$6,250,000 (us/canada rentals)',
#  '$1.8 million (est. us/ canada rentals)',
#  '$2.5 million (est. us/ canada rentals)',
#  '$51.6 million (united states/canada)',
#  '$12.3 million (us and canada rentals)',
#  '$1,700,000 (us/canada rentals)',
#  '$3,100,000 (us/canada rentals)',
#  '$3.75 million (us and canadian rentals)',
#  '$2.3 million (us and canadian rentals)',
#  '$40 million',
#  '$303 million',
#  '$25.4 million',
#  '$25.1 million',
#  '$4.6 million (u.s./canada rentals)',
#  '$3.5 million',
#  '$5 million (rentals)',
#  '$21,745,500',
#  '$22.1 million',
#  '$2,550,000 (us/ canada)',
#  '$3,000,000 (us/ canada)',
#  '$4,350,000 (us/ canada rentals)',
#  '$4.2 million (us/canada) (rentals)',
#  '$22.2 million',
#  'est. $1,600,000 (us/ canada)',
#  '$4,000,000 (us/ canada)',
#  '$2,250,000 (us/ canada)',
#  'est. $3,500,000 (us/ canada)',
#  '$103.1 million',
#  '$1,275,000',
#  '$3,500,000 (us/ canada rentals)',
#  '$4,000,000 (us/canada rentals)',
#  '$28,068,222',
#  '$6.2 million (est. us/ canada rentals)',
#  '$22,565,634',
#  '$16,207,116',
#  '$3,000,000 (us/ canada)',
#  '$1,900,000 (us/ canada)',
#  '$4,000,000 (us/ canada)',
#  '$378 million',
#  '$5 million (u.s./canada rentals)',
#  '$21,540,050',
#  '$2,250,000 (us/ canada)',
#  '$4,150,000 (us/ canada rentals)',
#  '$3.3 million  (us/ canada rentals)',
#  '$51,264,000',
#  '$1.3 million (us/ canada rentals)',
#  '$5.5 million (us/ canada rentals)',
#  '$18,607,492',
#  '$4 million (rentals) (us/canada)',
#  '$191 million',
#  '$5.1 million (north america) (rentals)',
#  '$17.9 million',
#  '$4,610,000 (us/canada) (rentals)',
#  '$6,100,000 (us/ canada rentals)',
#  '$22,583,370',
#  '$2 million',
#  '$32 million',
#  '$7 million (us/canada rentals)',
#  '$4 million (rentals) (us/canada)',
#  '$10 million (us/canada rentals)',
#  '$6.6 million (us/canada rentals)',
#  '$20,000,000',
#  '$36,853,000',
#  '$5.5 million (north american rentals)',
#  '$21,873,000',
#  '$10.5 million (us and canada rentals)',
#  '$36 million',
#  '$169 million',
#  '$29 million',
#  '$36 –39.6 million',
#  '$20,931,111',
#  '$2.9 million',
#  '$5 million',
#  '$18 million',
#  '$11 million',
#  '$60 million',
#  '$16 million (usa)',
#  '$14.1 million',
#  '$63.5 million',
#  '$8 million',
#  'us$50 million',
#  '$7.4 million',
#  '$4,304,286 (us)',
#  '$8.4 million',
#  '$27.6 million',
#  '$11.1 million (usa)',
#  '$21.3 million',
#  '$9.7 million (u.s. and canada only)',
#  '$13 million',
#  '$38.7 million',
#  '$18,564,613',
#  '$22.3 million',
#  '$13,687,027',
#  '>$121 million',
#  '$222.7 million',
#  '$8,153,677 (united states)',
#  '$233 million',
#  '$18.1 million',
#  '$47.4 million',
#  '$34.8 million',
#  '$15.1 million',
#  '$7.3 million',
#  '$46.7 million (usa)',
#  '$440.1 million',
#  '$2.8 million',
#  '$96 million',
#  '$50.8 million',
#  '$504.1 million',
#  '$27.2 million',
#  '$57 million',
#  '$12.9 million',
#  '$24.1 million',
#  '$44.9 million',
#  '$154.9 million',
#  '$53.9 million',
#  '$21 million',
#  '$39 million',
#  '$45.6 million',
#  '$8,878,839 (us)',
#  '$968.5 million',
#  '$50.2 million',
#  '$3,337,685',
#  '$189.8 million',
#  '$43.2 million',
#  '$17.6 million',
#  '$40,070,995',
#  '$11 million',
#  '$37.6 million',
#  '$346.1 million',
#  '$24,670,346',
#  '$13.4 million (domestic)',
#  '$17.7 million',
#  '$373 million',
#  '$23.9 million',
#  '$34.3 million (north america)',
#  '$32.7 million',
#  '$37.7 million',
#  '$325.3 million',
#  '$26,491,793',
#  '$22.9 million',
#  '$320.7 million',
#  '$18.3 million',
#  '$59.9 million',
#  '$252.7 million',
#  '$174.4 million',
#  '$27.8 million',
#  '$15.4 million',
#  '$178 million',
#  '$28.9 million',
#  '$4.4 million',
#  '$304.3 million',
#  '$92.1 million',
#  '$12.2 million',
#  '$363.3 million',
#  '$50.6 million (us)',
#  '$36.8 million',
#  '$19.4 million',
#  '$448.2 million',
#  '$134.4 million',
#  '$6.2 million (north america)',
#  '$497.4 million',
#  '$90.9 million',
#  '$96.2 million',
#  '$349.8 million',
#  '$110.3 million',
#  '$136.7 million',
#  '$183.6 million',
#  '$169.6 million',
#  '$44.5 million',
#  '$186.1 million',
#  '$165.3 million',
#  '$18.6 million',
#  '$577.4 million',
#  '$115 million',
#  '$115.1 million',
#  '$80.7 million',
#  '$273.1 million',
#  '$18 million',
#  '$395.5 million',
#  '$19.3 million',
#  '$172.9 million',
#  '$109.6 million',
#  '$135.7 million',
#  '$62.9 million',
#  '$28.7 million',
#  '$71.4 million',
#  '$55.5 million',
#  '$940.3 million',
#  '$654.3 million',
#  '$160.8 million',
#  '$250.4 million',
#  '$182.3 million',
#  '$9,638,389',
#  '$6.5 million',
#  '$64.5 million',
#  '$33.1 million',
#  '$145.5 million',
#  '$1,108,356',
#  '$72.2 million',
#  '$314,402',
#  '$134.7 million',
#  '$633 million',
#  '$347.5 million',
#  '$9 million',
#  '$52.9 million',
#  '$198.6 million',
#  '$27.6 million',
#  '$144.1 million',
#  '$86.4 million',
#  '$61.7 million',
#  '$15.4 million',
#  '$314.4 million',
#  '$745 million',
#  '$42.9 million',
#  '$11 million',
#  '$120.5 million',
#  '$87.1 million',
#  '$102.3 million',
#  '$462 million',
#  '$1.066 billion',
#  '$58.5 million',
#  '$91.5 million',
#  '$110.8 million',
#  '$137.6 million',
#  '$169.3 million',
#  '$961 million',
#  '$620.7 million',
#  '$65.3 million',
#  '$146.6 million',
#  '$340.5 million',
#  '$459.2 million',
#  '$70.6 million',
#  '$51.5 million',
#  '$419.7 million',
#  '$521.3 million',
#  '$149.3 million',
#  '$275,776',
#  '$252.9 million',
#  '$310 million',
#  '$212.9 million',
#  '$23.1 million',
#  '$106.4 million',
#  '$170  million',
#  '$109 million',
#  '$735.1 million',
#  '$292.8 million',
#  'us$ 203.2 million',
#  '$11.3 million',
#  '$325 million',
#  '$96.8 million',
#  '$270 million',
#  '$1.025 billion',
#  '$82.7 million',
#  '$336.4 million',
#  '$1.067 billion',
#  '$215.3 million',
#  '$75.5 million',
#  '$60.3 million',
#  '$592.4 million',
#  '$55,513',
#  '$400.1 million',
#  '₹ 50 crore (us$7.0 million)',
#  '$39.2 million',
#  '$30.9 million',
#  '$10.7 million',
#  '$1.046 billion',
#  '$562.1 million',
#  '$50.1 million',
#  '$165.2 million',
#  '$146 million',
#  '$284.1 million',
#  '$34.8 million',
#  '$540.4 million',
#  '$56 million',
#  '$81.5 million',
#  '$471.2 million',
#  '$493.3 million',
#  '$743.6 million',
#  '$260.5 million',
#  '$239.3 million',
#  '$1.280 billion',
#  '$117.9 million',
#  '$80.4 million',
#  '$21.3 million',
#  '$39.2 million',
#  '$758.5 million',
#  '$147 million',
#  'est. ₹ 79.43 crore (us$11 million)',
#  '$100.7 million',
#  '$657.8 million',
#  '$213.1 million',
#  '$45.7 million',
#  '$543 million',
#  '$17.1 million',
#  '$209 million',
#  '$858 million',
#  'est. ₹1.65 billion',
#  '$332.2 million',
#  '$52.1 million',
#  '$1.024 billion',
#  '$966.6 million',
#  '$17 million',
#  '$299.5 million',
#  '$1.029 billion',
#  '$195.2 million',
#  '$143.7 million',
#  '$10.4 million',
#  '$690.8 million',
#  '$127.4 million',
#  '$1.264 billion',
#  '$25.1 million',
#  '$794.9 million',
#  '$383.9 million',
#  '₹ 833.5 million',
#  '$807.8 million',
#  '$133.4 million',
#  '$1.243 billion',
#  '$197.7 million',
#  '$174 million',
#  '$529.3 million',
#  '$349.5 million',
#  '$353.3 million',
#  '$7.7\n million',
#  '$1.051 billion',
#  '$1.073 billion',
#  '$1.657 billion',
#  '$491.7 million',
#  '$1.450 billion',
#  '$141.9 million',
#  '$70 million',
#  '$115.7 million']

# %%
amount_pattern=re.compile('.*?\$.*?(?P<amount>[0-9,.]+)')
amount_pattern
# Out:
# re.compile(r'.*?\$.*?(?P<amount>[0-9,.]+)', re.UNICODE)

# %%
place_holder_pattern=re.compile('.*?(?P<mb>million|billion)')
place_holder_pattern
# Out:
# re.compile(r'.*?(?P<mb>million|billion)', re.UNICODE)

# %%
bov=box_office_values[1]
bov
# Out:
# '$418 million'

# %%
place_holder_pattern.search(bov).groups()
# Out:
# ('million',)

# %%
[(x,{'pcv': place_holder_pattern.search(x).groups()[0]}) for x in box_office_values if place_holder_pattern.search(x) is not None]
# Out:
# [('$418 million', {'pcv': 'million'}),
#  ('$164 million', {'pcv': 'million'}),
#  ('$76.4–$83.3 million', {'pcv': 'million'}),
#  ('$1.3 million (est. united states/canada rentals, 1941)',
#   {'pcv': 'million'}),
#  ('$267.4 million', {'pcv': 'million'}),
#  ('$3.275 million (worldwide rentals)', {'pcv': 'million'}),
#  ('$65 million', {'pcv': 'million'}),
#  ('$3.7 million (u.s. rental) $575,000 (foreign rental)', {'pcv': 'million'}),
#  ('$263.6 million', {'pcv': 'million'}),
#  ('$5.6 million (us, 1951)', {'pcv': 'million'}),
#  ('$2.1 million (us rentals)', {'pcv': 'million'}),
#  ('$87.4 million', {'pcv': 'million'}),
#  ('$1 million (us)', {'pcv': 'million'}),
#  ('$2.6 million (us)', {'pcv': 'million'}),
#  ('$1.75 million (us and canadian rentals)', {'pcv': 'million'}),
#  ('$28.2 million', {'pcv': 'million'}),
#  ('$187 million', {'pcv': 'million'}),
#  ('$2.1 million (us)', {'pcv': 'million'}),
#  ('$1.6 million (us)', {'pcv': 'million'}),
#  ('$1.7 million (us)', {'pcv': 'million'}),
#  ('$2.75 million (us)', {'pcv': 'million'}),
#  ('$1.75 million (us rentals)', {'pcv': 'million'}),
#  ('$1.8 million (est. us/ canada rentals)', {'pcv': 'million'}),
#  ('$2.5 million (est. us/ canada rentals)', {'pcv': 'million'}),
#  ('$51.6 million (united states/canada)', {'pcv': 'million'}),
#  ('$12.3 million (us and canada rentals)', {'pcv': 'million'}),
#  ('$3.75 million (us and canadian rentals)', {'pcv': 'million'}),
#  ('$2.3 million (us and canadian rentals)', {'pcv': 'million'}),
#  ('$40 million', {'pcv': 'million'}),
#  ('$303 million', {'pcv': 'million'}),
#  ('$25.4 million', {'pcv': 'million'}),
#  ('$25.1 million', {'pcv': 'million'}),
#  ('$4.6 million (u.s./canada rentals)', {'pcv': 'million'}),
#  ('$3.5 million', {'pcv': 'million'}),
#  ('$5 million (rentals)', {'pcv': 'million'}),
#  ('$22.1 million', {'pcv': 'million'}),
#  ('$4.2 million (us/canada) (rentals)', {'pcv': 'million'}),
#  ('$22.2 million', {'pcv': 'million'}),
#  ('$103.1 million', {'pcv': 'million'}),
#  ('$6.2 million (est. us/ canada rentals)', {'pcv': 'million'}),
#  ('$378 million', {'pcv': 'million'}),
#  ('$5 million (u.s./canada rentals)', {'pcv': 'million'}),
#  ('$3.3 million  (us/ canada rentals)', {'pcv': 'million'}),
#  ('$1.3 million (us/ canada rentals)', {'pcv': 'million'}),
#  ('$5.5 million (us/ canada rentals)', {'pcv': 'million'}),
#  ('$4 million (rentals) (us/canada)', {'pcv': 'million'}),
#  ('$191 million', {'pcv': 'million'}),
#  ('$5.1 million (north america) (rentals)', {'pcv': 'million'}),
#  ('$17.9 million', {'pcv': 'million'}),
#  ('$2 million', {'pcv': 'million'}),
#  ('$32 million', {'pcv': 'million'}),
#  ('$7 million (us/canada rentals)', {'pcv': 'million'}),
#  ('$4 million (rentals) (us/canada)', {'pcv': 'million'}),
#  ('$10 million (us/canada rentals)', {'pcv': 'million'}),
#  ('$6.6 million (us/canada rentals)', {'pcv': 'million'}),
#  ('$5.5 million (north american rentals)', {'pcv': 'million'}),
#  ('$10.5 million (us and canada rentals)', {'pcv': 'million'}),
#  ('$36 million', {'pcv': 'million'}),
#  ('$169 million', {'pcv': 'million'}),
#  ('$29 million', {'pcv': 'million'}),
#  ('$36 –39.6 million', {'pcv': 'million'}),
#  ('$2.9 million', {'pcv': 'million'}),
#  ('$5 million', {'pcv': 'million'}),
#  ('$18 million', {'pcv': 'million'}),
#  ('$11 million', {'pcv': 'million'}),
#  ('$60 million', {'pcv': 'million'}),
#  ('$16 million (usa)', {'pcv': 'million'}),
#  ('$14.1 million', {'pcv': 'million'}),
#  ('$63.5 million', {'pcv': 'million'}),
#  ('$8 million', {'pcv': 'million'}),
#  ('us$50 million', {'pcv': 'million'}),
#  ('$7.4 million', {'pcv': 'million'}),
#  ('$8.4 million', {'pcv': 'million'}),
#  ('$27.6 million', {'pcv': 'million'}),
#  ('$11.1 million (usa)', {'pcv': 'million'}),
#  ('$21.3 million', {'pcv': 'million'}),
#  ('$9.7 million (u.s. and canada only)', {'pcv': 'million'}),
#  ('$13 million', {'pcv': 'million'}),
#  ('$38.7 million', {'pcv': 'million'}),
#  ('$22.3 million', {'pcv': 'million'}),
#  ('>$121 million', {'pcv': 'million'}),
#  ('$222.7 million', {'pcv': 'million'}),
#  ('$233 million', {'pcv': 'million'}),
#  ('$18.1 million', {'pcv': 'million'}),
#  ('$47.4 million', {'pcv': 'million'}),
#  ('$34.8 million', {'pcv': 'million'}),
#  ('$15.1 million', {'pcv': 'million'}),
#  ('$7.3 million', {'pcv': 'million'}),
#  ('$46.7 million (usa)', {'pcv': 'million'}),
#  ('$440.1 million', {'pcv': 'million'}),
#  ('$2.8 million', {'pcv': 'million'}),
#  ('$96 million', {'pcv': 'million'}),
#  ('$50.8 million', {'pcv': 'million'}),
#  ('$504.1 million', {'pcv': 'million'}),
#  ('$27.2 million', {'pcv': 'million'}),
#  ('$57 million', {'pcv': 'million'}),
#  ('$12.9 million', {'pcv': 'million'}),
#  ('$24.1 million', {'pcv': 'million'}),
#  ('$44.9 million', {'pcv': 'million'}),
#  ('$154.9 million', {'pcv': 'million'}),
#  ('$53.9 million', {'pcv': 'million'}),
#  ('$21 million', {'pcv': 'million'}),
#  ('$39 million', {'pcv': 'million'}),
#  ('$45.6 million', {'pcv': 'million'}),
#  ('$968.5 million', {'pcv': 'million'}),
#  ('$50.2 million', {'pcv': 'million'}),
#  ('$189.8 million', {'pcv': 'million'}),
#  ('$43.2 million', {'pcv': 'million'}),
#  ('$17.6 million', {'pcv': 'million'}),
#  ('$11 million', {'pcv': 'million'}),
#  ('$37.6 million', {'pcv': 'million'}),
#  ('$346.1 million', {'pcv': 'million'}),
#  ('$13.4 million (domestic)', {'pcv': 'million'}),
#  ('$17.7 million', {'pcv': 'million'}),
#  ('$373 million', {'pcv': 'million'}),
#  ('$23.9 million', {'pcv': 'million'}),
#  ('$34.3 million (north america)', {'pcv': 'million'}),
#  ('$32.7 million', {'pcv': 'million'}),
#  ('$37.7 million', {'pcv': 'million'}),
#  ('$325.3 million', {'pcv': 'million'}),
#  ('$22.9 million', {'pcv': 'million'}),
#  ('$320.7 million', {'pcv': 'million'}),
#  ('$18.3 million', {'pcv': 'million'}),
#  ('$59.9 million', {'pcv': 'million'}),
#  ('$252.7 million', {'pcv': 'million'}),
#  ('$174.4 million', {'pcv': 'million'}),
#  ('$27.8 million', {'pcv': 'million'}),
#  ('$15.4 million', {'pcv': 'million'}),
#  ('$178 million', {'pcv': 'million'}),
#  ('$28.9 million', {'pcv': 'million'}),
#  ('$4.4 million', {'pcv': 'million'}),
#  ('$304.3 million', {'pcv': 'million'}),
#  ('$92.1 million', {'pcv': 'million'}),
#  ('$12.2 million', {'pcv': 'million'}),
#  ('$363.3 million', {'pcv': 'million'}),
#  ('$50.6 million (us)', {'pcv': 'million'}),
#  ('$36.8 million', {'pcv': 'million'}),
#  ('$19.4 million', {'pcv': 'million'}),
#  ('$448.2 million', {'pcv': 'million'}),
#  ('$134.4 million', {'pcv': 'million'}),
#  ('$6.2 million (north america)', {'pcv': 'million'}),
#  ('$497.4 million', {'pcv': 'million'}),
#  ('$90.9 million', {'pcv': 'million'}),
#  ('$96.2 million', {'pcv': 'million'}),
#  ('$349.8 million', {'pcv': 'million'}),
#  ('$110.3 million', {'pcv': 'million'}),
#  ('$136.7 million', {'pcv': 'million'}),
#  ('$183.6 million', {'pcv': 'million'}),
#  ('$169.6 million', {'pcv': 'million'}),
#  ('$44.5 million', {'pcv': 'million'}),
#  ('$186.1 million', {'pcv': 'million'}),
#  ('$165.3 million', {'pcv': 'million'}),
#  ('$18.6 million', {'pcv': 'million'}),
#  ('$577.4 million', {'pcv': 'million'}),
#  ('$115 million', {'pcv': 'million'}),
#  ('$115.1 million', {'pcv': 'million'}),
#  ('$80.7 million', {'pcv': 'million'}),
#  ('$273.1 million', {'pcv': 'million'}),
#  ('$18 million', {'pcv': 'million'}),
#  ('$395.5 million', {'pcv': 'million'}),
#  ('$19.3 million', {'pcv': 'million'}),
#  ('$172.9 million', {'pcv': 'million'}),
#  ('$109.6 million', {'pcv': 'million'}),
#  ('$135.7 million', {'pcv': 'million'}),
#  ('$62.9 million', {'pcv': 'million'}),
#  ('$28.7 million', {'pcv': 'million'}),
#  ('$71.4 million', {'pcv': 'million'}),
#  ('$55.5 million', {'pcv': 'million'}),
#  ('$940.3 million', {'pcv': 'million'}),
#  ('$654.3 million', {'pcv': 'million'}),
#  ('$160.8 million', {'pcv': 'million'}),
#  ('$250.4 million', {'pcv': 'million'}),
#  ('$182.3 million', {'pcv': 'million'}),
#  ('$6.5 million', {'pcv': 'million'}),
#  ('$64.5 million', {'pcv': 'million'}),
#  ('$33.1 million', {'pcv': 'million'}),
#  ('$145.5 million', {'pcv': 'million'}),
#  ('$72.2 million', {'pcv': 'million'}),
#  ('$134.7 million', {'pcv': 'million'}),
#  ('$633 million', {'pcv': 'million'}),
#  ('$347.5 million', {'pcv': 'million'}),
#  ('$9 million', {'pcv': 'million'}),
#  ('$52.9 million', {'pcv': 'million'}),
#  ('$198.6 million', {'pcv': 'million'}),
#  ('$27.6 million', {'pcv': 'million'}),
#  ('$144.1 million', {'pcv': 'million'}),
#  ('$86.4 million', {'pcv': 'million'}),
#  ('$61.7 million', {'pcv': 'million'}),
#  ('$15.4 million', {'pcv': 'million'}),
#  ('$314.4 million', {'pcv': 'million'}),
#  ('$745 million', {'pcv': 'million'}),
#  ('$42.9 million', {'pcv': 'million'}),
#  ('$11 million', {'pcv': 'million'}),
#  ('$120.5 million', {'pcv': 'million'}),
#  ('$87.1 million', {'pcv': 'million'}),
#  ('$102.3 million', {'pcv': 'million'}),
#  ('$462 million', {'pcv': 'million'}),
#  ('$1.066 billion', {'pcv': 'billion'}),
#  ('$58.5 million', {'pcv': 'million'}),
#  ('$91.5 million', {'pcv': 'million'}),
#  ('$110.8 million', {'pcv': 'million'}),
#  ('$137.6 million', {'pcv': 'million'}),
#  ('$169.3 million', {'pcv': 'million'}),
#  ('$961 million', {'pcv': 'million'}),
#  ('$620.7 million', {'pcv': 'million'}),
#  ('$65.3 million', {'pcv': 'million'}),
#  ('$146.6 million', {'pcv': 'million'}),
#  ('$340.5 million', {'pcv': 'million'}),
#  ('$459.2 million', {'pcv': 'million'}),
#  ('$70.6 million', {'pcv': 'million'}),
#  ('$51.5 million', {'pcv': 'million'}),
#  ('$419.7 million', {'pcv': 'million'}),
#  ('$521.3 million', {'pcv': 'million'}),
#  ('$149.3 million', {'pcv': 'million'}),
#  ('$252.9 million', {'pcv': 'million'}),
#  ('$310 million', {'pcv': 'million'}),
#  ('$212.9 million', {'pcv': 'million'}),
#  ('$23.1 million', {'pcv': 'million'}),
#  ('$106.4 million', {'pcv': 'million'}),
#  ('$170  million', {'pcv': 'million'}),
#  ('$109 million', {'pcv': 'million'}),
#  ('$735.1 million', {'pcv': 'million'}),
#  ('$292.8 million', {'pcv': 'million'}),
#  ('us$ 203.2 million', {'pcv': 'million'}),
#  ('$11.3 million', {'pcv': 'million'}),
#  ('$325 million', {'pcv': 'million'}),
#  ('$96.8 million', {'pcv': 'million'}),
#  ('$270 million', {'pcv': 'million'}),
#  ('$1.025 billion', {'pcv': 'billion'}),
#  ('$82.7 million', {'pcv': 'million'}),
#  ('$336.4 million', {'pcv': 'million'}),
#  ('$1.067 billion', {'pcv': 'billion'}),
#  ('$215.3 million', {'pcv': 'million'}),
#  ('$75.5 million', {'pcv': 'million'}),
#  ('$60.3 million', {'pcv': 'million'}),
#  ('$592.4 million', {'pcv': 'million'}),
#  ('$400.1 million', {'pcv': 'million'}),
#  ('₹ 50 crore (us$7.0 million)', {'pcv': 'million'}),
#  ('$39.2 million', {'pcv': 'million'}),
#  ('$30.9 million', {'pcv': 'million'}),
#  ('$10.7 million', {'pcv': 'million'}),
#  ('$1.046 billion', {'pcv': 'billion'}),
#  ('$562.1 million', {'pcv': 'million'}),
#  ('$50.1 million', {'pcv': 'million'}),
#  ('$165.2 million', {'pcv': 'million'}),
#  ('$146 million', {'pcv': 'million'}),
#  ('$284.1 million', {'pcv': 'million'}),
#  ('$34.8 million', {'pcv': 'million'}),
#  ('$540.4 million', {'pcv': 'million'}),
#  ('$56 million', {'pcv': 'million'}),
#  ('$81.5 million', {'pcv': 'million'}),
#  ('$471.2 million', {'pcv': 'million'}),
#  ('$493.3 million', {'pcv': 'million'}),
#  ('$743.6 million', {'pcv': 'million'}),
#  ('$260.5 million', {'pcv': 'million'}),
#  ('$239.3 million', {'pcv': 'million'}),
#  ('$1.280 billion', {'pcv': 'billion'}),
#  ('$117.9 million', {'pcv': 'million'}),
#  ('$80.4 million', {'pcv': 'million'}),
#  ('$21.3 million', {'pcv': 'million'}),
#  ('$39.2 million', {'pcv': 'million'}),
#  ('$758.5 million', {'pcv': 'million'}),
#  ('$147 million', {'pcv': 'million'}),
#  ('est. ₹ 79.43 crore (us$11 million)', {'pcv': 'million'}),
#  ('$100.7 million', {'pcv': 'million'}),
#  ('$657.8 million', {'pcv': 'million'}),
#  ('$213.1 million', {'pcv': 'million'}),
#  ('$45.7 million', {'pcv': 'million'}),
#  ('$543 million', {'pcv': 'million'}),
#  ('$17.1 million', {'pcv': 'million'}),
#  ('$209 million', {'pcv': 'million'}),
#  ('$858 million', {'pcv': 'million'}),
#  ('est. ₹1.65 billion', {'pcv': 'billion'}),
#  ('$332.2 million', {'pcv': 'million'}),
#  ('$52.1 million', {'pcv': 'million'}),
#  ('$1.024 billion', {'pcv': 'billion'}),
#  ('$966.6 million', {'pcv': 'million'}),
#  ('$17 million', {'pcv': 'million'}),
#  ('$299.5 million', {'pcv': 'million'}),
#  ('$1.029 billion', {'pcv': 'billion'}),
#  ('$195.2 million', {'pcv': 'million'}),
#  ('$143.7 million', {'pcv': 'million'}),
#  ('$10.4 million', {'pcv': 'million'}),
#  ('$690.8 million', {'pcv': 'million'}),
#  ('$127.4 million', {'pcv': 'million'}),
#  ('$1.264 billion', {'pcv': 'billion'}),
#  ('$25.1 million', {'pcv': 'million'}),
#  ('$794.9 million', {'pcv': 'million'}),
#  ('$383.9 million', {'pcv': 'million'}),
#  ('₹ 833.5 million', {'pcv': 'million'}),
#  ('$807.8 million', {'pcv': 'million'}),
#  ('$133.4 million', {'pcv': 'million'}),
#  ('$1.243 billion', {'pcv': 'billion'}),
#  ('$197.7 million', {'pcv': 'million'}),
#  ('$174 million', {'pcv': 'million'}),
#  ('$529.3 million', {'pcv': 'million'}),
#  ('$349.5 million', {'pcv': 'million'}),
#  ('$353.3 million', {'pcv': 'million'}),
#  ('$7.7\n million', {'pcv': 'million'}),
#  ('$1.051 billion', {'pcv': 'billion'}),
#  ('$1.073 billion', {'pcv': 'billion'}),
#  ('$1.657 billion', {'pcv': 'billion'}),
#  ('$491.7 million', {'pcv': 'million'}),
#  ('$1.450 billion', {'pcv': 'billion'}),
#  ('$141.9 million', {'pcv': 'million'}),
#  ('$70 million', {'pcv': 'million'}),
#  ('$115.7 million', {'pcv': 'million'})]

# %%
amount_pattern.match(box_office_values[3]).groups()
# Out:
# ('76.4',)

# %%
place_holder_pattern.match(box_office_values[1]).groups()
# Out:
# ('million',)

# %%
[x if place_holder_pattern.search(x) is None else (i, place_holder_pattern.search(x).groupdict(),x) for i,x in enumerate(box_office_values)]
# Out:
# ['$45.472',
#  (1, {'mb': 'million'}, '$418 million'),
#  (2, {'mb': 'million'}, '$164 million'),
#  (3, {'mb': 'million'}, '$76.4–$83.3 million'),
#  '$960,000 (worldwide rentals)',
#  (5,
#   {'mb': 'million'},
#   '$1.3 million (est. united states/canada rentals, 1941)'),
#  (6, {'mb': 'million'}, '$267.4 million'),
#  '$1,135,000 (worldwide rentals)',
#  '$799,000',
#  '$3,355,000 (worldwide rentals)',
#  (10, {'mb': 'million'}, '$3.275 million (worldwide rentals)'),
#  (11, {'mb': 'million'}, '$65 million'),
#  '$3,165,000 (worldwide rentals)',
#  '$2,560,000 (worldwide rentals)',
#  (14,
#   {'mb': 'million'},
#   '$3.7 million (u.s. rental) $575,000 (foreign rental)'),
#  '$1,625,000 (worldwide rentals)',
#  (16, {'mb': 'million'}, '$263.6 million'),
#  '$4,100,000 (worldwide rentals)',
#  (18, {'mb': 'million'}, '$5.6 million (us, 1951)'),
#  (19, {'mb': 'million'}, '$2.1 million (us rentals)'),
#  (20, {'mb': 'million'}, '$87.4 million'),
#  (21, {'mb': 'million'}, '$1 million (us)'),
#  (22, {'mb': 'million'}, '$2.6 million (us)'),
#  (23, {'mb': 'million'}, '$1.75 million (us and canadian rentals)'),
#  (24, {'mb': 'million'}, '$28.2 million'),
#  '$2,150,000 (us)',
#  (26, {'mb': 'million'}, '$187 million'),
#  (27, {'mb': 'million'}, '$2.1 million (us)'),
#  (28, {'mb': 'million'}, '$1.6 million (us)'),
#  (29, {'mb': 'million'}, '$1.7 million (us)'),
#  (30, {'mb': 'million'}, '$2.75 million (us)'),
#  (31, {'mb': 'million'}, '$1.75 million (us rentals)'),
#  '$6,250,000 (us/canada rentals)',
#  (33, {'mb': 'million'}, '$1.8 million (est. us/ canada rentals)'),
#  (34, {'mb': 'million'}, '$2.5 million (est. us/ canada rentals)'),
#  (35, {'mb': 'million'}, '$51.6 million (united states/canada)'),
#  (36, {'mb': 'million'}, '$12.3 million (us and canada rentals)'),
#  '$1,700,000 (us/canada rentals)',
#  '$3,100,000 (us/canada rentals)',
#  (39, {'mb': 'million'}, '$3.75 million (us and canadian rentals)'),
#  (40, {'mb': 'million'}, '$2.3 million (us and canadian rentals)'),
#  (41, {'mb': 'million'}, '$40 million'),
#  (42, {'mb': 'million'}, '$303 million'),
#  (43, {'mb': 'million'}, '$25.4 million'),
#  (44, {'mb': 'million'}, '$25.1 million'),
#  (45, {'mb': 'million'}, '$4.6 million (u.s./canada rentals)'),
#  (46, {'mb': 'million'}, '$3.5 million'),
#  (47, {'mb': 'million'}, '$5 million (rentals)'),
#  '$21,745,500',
#  (49, {'mb': 'million'}, '$22.1 million'),
#  '$2,550,000 (us/ canada)',
#  '$3,000,000 (us/ canada)',
#  '$4,350,000 (us/ canada rentals)',
#  (53, {'mb': 'million'}, '$4.2 million (us/canada) (rentals)'),
#  (54, {'mb': 'million'}, '$22.2 million'),
#  'est. $1,600,000 (us/ canada)',
#  '$4,000,000 (us/ canada)',
#  '$2,250,000 (us/ canada)',
#  'est. $3,500,000 (us/ canada)',
#  (59, {'mb': 'million'}, '$103.1 million'),
#  '$1,275,000',
#  '$3,500,000 (us/ canada rentals)',
#  '$4,000,000 (us/canada rentals)',
#  '$28,068,222',
#  (64, {'mb': 'million'}, '$6.2 million (est. us/ canada rentals)'),
#  '$22,565,634',
#  '$16,207,116',
#  '$3,000,000 (us/ canada)',
#  '$1,900,000 (us/ canada)',
#  '$4,000,000 (us/ canada)',
#  (70, {'mb': 'million'}, '$378 million'),
#  (71, {'mb': 'million'}, '$5 million (u.s./canada rentals)'),
#  '$21,540,050',
#  '$2,250,000 (us/ canada)',
#  '$4,150,000 (us/ canada rentals)',
#  (75, {'mb': 'million'}, '$3.3 million  (us/ canada rentals)'),
#  '$51,264,000',
#  (77, {'mb': 'million'}, '$1.3 million (us/ canada rentals)'),
#  (78, {'mb': 'million'}, '$5.5 million (us/ canada rentals)'),
#  '$18,607,492',
#  (80, {'mb': 'million'}, '$4 million (rentals) (us/canada)'),
#  (81, {'mb': 'million'}, '$191 million'),
#  (82, {'mb': 'million'}, '$5.1 million (north america) (rentals)'),
#  (83, {'mb': 'million'}, '$17.9 million'),
#  '$4,610,000 (us/canada) (rentals)',
#  '$6,100,000 (us/ canada rentals)',
#  '$22,583,370',
#  (87, {'mb': 'million'}, '$2 million'),
#  (88, {'mb': 'million'}, '$32 million'),
#  (89, {'mb': 'million'}, '$7 million (us/canada rentals)'),
#  (90, {'mb': 'million'}, '$4 million (rentals) (us/canada)'),
#  (91, {'mb': 'million'}, '$10 million (us/canada rentals)'),
#  (92, {'mb': 'million'}, '$6.6 million (us/canada rentals)'),
#  '$20,000,000',
#  '$36,853,000',
#  (95, {'mb': 'million'}, '$5.5 million (north american rentals)'),
#  '$21,873,000',
#  (97, {'mb': 'million'}, '$10.5 million (us and canada rentals)'),
#  (98, {'mb': 'million'}, '$36 million'),
#  (99, {'mb': 'million'}, '$169 million'),
#  (100, {'mb': 'million'}, '$29 million'),
#  (101, {'mb': 'million'}, '$36 –39.6 million'),
#  '$20,931,111',
#  (103, {'mb': 'million'}, '$2.9 million'),
#  (104, {'mb': 'million'}, '$5 million'),
#  (105, {'mb': 'million'}, '$18 million'),
#  (106, {'mb': 'million'}, '$11 million'),
#  (107, {'mb': 'million'}, '$60 million'),
#  (108, {'mb': 'million'}, '$16 million (usa)'),
#  (109, {'mb': 'million'}, '$14.1 million'),
#  (110, {'mb': 'million'}, '$63.5 million'),
#  (111, {'mb': 'million'}, '$8 million'),
#  (112, {'mb': 'million'}, 'us$50 million'),
#  (113, {'mb': 'million'}, '$7.4 million'),
#  '$4,304,286 (us)',
#  (115, {'mb': 'million'}, '$8.4 million'),
#  (116, {'mb': 'million'}, '$27.6 million'),
#  (117, {'mb': 'million'}, '$11.1 million (usa)'),
#  (118, {'mb': 'million'}, '$21.3 million'),
#  (119, {'mb': 'million'}, '$9.7 million (u.s. and canada only)'),
#  (120, {'mb': 'million'}, '$13 million'),
#  (121, {'mb': 'million'}, '$38.7 million'),
#  '$18,564,613',
#  (123, {'mb': 'million'}, '$22.3 million'),
#  '$13,687,027',
#  (125, {'mb': 'million'}, '>$121 million'),
#  (126, {'mb': 'million'}, '$222.7 million'),
#  '$8,153,677 (united states)',
#  (128, {'mb': 'million'}, '$233 million'),
#  (129, {'mb': 'million'}, '$18.1 million'),
#  (130, {'mb': 'million'}, '$47.4 million'),
#  (131, {'mb': 'million'}, '$34.8 million'),
#  (132, {'mb': 'million'}, '$15.1 million'),
#  (256, {'mb': 'million'}, '$169.3 million'),
#  (257, {'mb': 'million'}, '$961 million'),
#  (258, {'mb': 'million'}, '$620.7 million'),
#  (259, {'mb': 'million'}, '$65.3 million'),
#  (260, {'mb': 'million'}, '$146.6 million'),
#  (261, {'mb': 'million'}, '$340.5 million'),
#  (262, {'mb': 'million'}, '$459.2 million'),
#  (263, {'mb': 'million'}, '$70.6 million'),
#  (264, {'mb': 'million'}, '$51.5 million'),
#  (265, {'mb': 'million'}, '$419.7 million'),
#  (266, {'mb': 'million'}, '$521.3 million'),
#  (267, {'mb': 'million'}, '$149.3 million'),
#  '$275,776',
#  (269, {'mb': 'million'}, '$252.9 million'),
#  (270, {'mb': 'million'}, '$310 million'),
#  (271, {'mb': 'million'}, '$212.9 million'),
#  (272, {'mb': 'million'}, '$23.1 million'),
#  (273, {'mb': 'million'}, '$106.4 million'),
#  (274, {'mb': 'million'}, '$170  million'),
#  (275, {'mb': 'million'}, '$109 million'),
#  (276, {'mb': 'million'}, '$735.1 million'),
#  (277, {'mb': 'million'}, '$292.8 million'),
#  (278, {'mb': 'million'}, 'us$ 203.2 million'),
#  (279, {'mb': 'million'}, '$11.3 million'),
#  (280, {'mb': 'million'}, '$325 million'),
#  (281, {'mb': 'million'}, '$96.8 million'),
#  (282, {'mb': 'million'}, '$270 million'),
#  (283, {'mb': 'billion'}, '$1.025 billion'),
#  (284, {'mb': 'million'}, '$82.7 million'),
#  (285, {'mb': 'million'}, '$336.4 million'),
#  (286, {'mb': 'billion'}, '$1.067 billion'),
#  (287, {'mb': 'million'}, '$215.3 million'),
#  (288, {'mb': 'million'}, '$75.5 million'),
#  (289, {'mb': 'million'}, '$60.3 million'),
#  (290, {'mb': 'million'}, '$592.4 million'),
#  '$55,513',
#  (292, {'mb': 'million'}, '$400.1 million'),
#  (293, {'mb': 'million'}, '₹ 50 crore (us$7.0 million)'),
#  (294, {'mb': 'million'}, '$39.2 million'),
#  (295, {'mb': 'million'}, '$30.9 million'),
#  (296, {'mb': 'million'}, '$10.7 million'),
#  (297, {'mb': 'billion'}, '$1.046 billion'),
#  (298, {'mb': 'million'}, '$562.1 million'),
#  (299, {'mb': 'million'}, '$50.1 million'),
#  (300, {'mb': 'million'}, '$165.2 million'),
#  (301, {'mb': 'million'}, '$146 million'),
#  (302, {'mb': 'million'}, '$284.1 million'),
#  (303, {'mb': 'million'}, '$34.8 million'),
#  (304, {'mb': 'million'}, '$540.4 million'),
#  (305, {'mb': 'million'}, '$56 million'),
#  (306, {'mb': 'million'}, '$81.5 million'),
#  (307, {'mb': 'million'}, '$471.2 million'),
#  (308, {'mb': 'million'}, '$493.3 million'),
#  (309, {'mb': 'million'}, '$743.6 million'),
#  (310, {'mb': 'million'}, '$260.5 million'),
#  (311, {'mb': 'million'}, '$239.3 million'),
#  (312, {'mb': 'billion'}, '$1.280 billion'),
#  (313, {'mb': 'million'}, '$117.9 million'),
#  (314, {'mb': 'million'}, '$80.4 million'),
#  (315, {'mb': 'million'}, '$21.3 million'),
#  (316, {'mb': 'million'}, '$39.2 million'),
#  (317, {'mb': 'million'}, '$758.5 million'),
#  (318, {'mb': 'million'}, '$147 million'),
#  (319, {'mb': 'million'}, 'est. ₹ 79.43 crore (us$11 million)'),
#  (320, {'mb': 'million'}, '$100.7 million'),
#  (321, {'mb': 'million'}, '$657.8 million'),
#  (322, {'mb': 'million'}, '$213.1 million'),
#  (323, {'mb': 'million'}, '$45.7 million'),
#  (324, {'mb': 'million'}, '$543 million'),
#  (325, {'mb': 'million'}, '$17.1 million'),
#  (326, {'mb': 'million'}, '$209 million'),
#  (327, {'mb': 'million'}, '$858 million'),
#  (328, {'mb': 'billion'}, 'est. ₹1.65 billion'),
#  (329, {'mb': 'million'}, '$332.2 million'),
#  (330, {'mb': 'million'}, '$52.1 million'),
#  (331, {'mb': 'billion'}, '$1.024 billion'),
#  (332, {'mb': 'million'}, '$966.6 million'),
#  (333, {'mb': 'million'}, '$17 million'),
#  (334, {'mb': 'million'}, '$299.5 million'),
#  (335, {'mb': 'billion'}, '$1.029 billion'),
#  (336, {'mb': 'million'}, '$195.2 million'),
#  (337, {'mb': 'million'}, '$143.7 million'),
#  (338, {'mb': 'million'}, '$10.4 million'),
#  (339, {'mb': 'million'}, '$690.8 million'),
#  (340, {'mb': 'million'}, '$127.4 million'),
#  (341, {'mb': 'billion'}, '$1.264 billion'),
#  (342, {'mb': 'million'}, '$25.1 million'),
#  (343, {'mb': 'million'}, '$794.9 million'),
#  (344, {'mb': 'million'}, '$383.9 million'),
#  (345, {'mb': 'million'}, '₹ 833.5 million'),
#  (346, {'mb': 'million'}, '$807.8 million'),
#  (347, {'mb': 'million'}, '$133.4 million'),
#  (348, {'mb': 'billion'}, '$1.243 billion'),
#  (349, {'mb': 'million'}, '$197.7 million'),
#  (350, {'mb': 'million'}, '$174 million'),
#  (351, {'mb': 'million'}, '$529.3 million'),
#  (352, {'mb': 'million'}, '$349.5 million'),
#  (353, {'mb': 'million'}, '$353.3 million'),
#  (354, {'mb': 'million'}, '$7.7\n million'),
#  (355, {'mb': 'billion'}, '$1.051 billion'),
#  (356, {'mb': 'billion'}, '$1.073 billion'),
#  (357, {'mb': 'billion'}, '$1.657 billion'),
#  (358, {'mb': 'million'}, '$491.7 million'),
#  (359, {'mb': 'billion'}, '$1.450 billion'),
#  (360, {'mb': 'million'}, '$141.9 million'),
#  (361, {'mb': 'million'}, '$70 million'),
#  (362, {'mb': 'million'}, '$115.7 million')]

# %%
# create a dictionary to store the regex compilers to search for amounts and million/billion.

bol = []

for i,x in enumerate(box_office_values):
    box_office_dict={}
    
    if amount_pattern.search(x) is not None:
        box_office_dict['amount'] = amount_pattern.search(x).groups()[0].strip('$')
    if place_holder_pattern.search(x) is not None:
        box_office_dict['place_holder'] = place_holder_pattern.search(x).groups()[0]
    
    if box_office_dict.get('amount') is not None:
        box_office_dict['value'] = float(box_office_dict['amount'].replace(",",""))
        
        if box_office_dict.get('place_holder') is not None:
            if box_office_dict.get('place_holder') == 'million':
                box_office_dict['value'] = box_office_dict['value']*1000000
                
            else:
                box_office_dict['value'] = box_office_dict['value']*1000000000
            
    bol.append(box_office_dict)
bol
# Out:
# [{'amount': '45.472', 'value': 45.472},
#  {'amount': '418', 'place_holder': 'million', 'value': 418000000.0},
#  {'amount': '164', 'place_holder': 'million', 'value': 164000000.0},
#  {'amount': '76.4', 'place_holder': 'million', 'value': 76400000.0},
#  {'amount': '960,000', 'value': 960000.0},
#  {'amount': '1.3', 'place_holder': 'million', 'value': 1300000.0},
#  {'amount': '267.4', 'place_holder': 'million', 'value': 267399999.99999997},
#  {'amount': '1,135,000', 'value': 1135000.0},
#  {'amount': '799,000', 'value': 799000.0},
#  {'amount': '3,355,000', 'value': 3355000.0},
#  {'amount': '3.275', 'place_holder': 'million', 'value': 3275000.0},
#  {'amount': '65', 'place_holder': 'million', 'value': 65000000.0},
#  {'amount': '3,165,000', 'value': 3165000.0},
#  {'amount': '2,560,000', 'value': 2560000.0},
#  {'amount': '3.7', 'place_holder': 'million', 'value': 3700000.0},
#  {'amount': '1,625,000', 'value': 1625000.0},
#  {'amount': '263.6', 'place_holder': 'million', 'value': 263600000.00000003},
#  {'amount': '4,100,000', 'value': 4100000.0},
#  {'amount': '5.6', 'place_holder': 'million', 'value': 5600000.0},
#  {'amount': '2.1', 'place_holder': 'million', 'value': 2100000.0},
#  {'amount': '87.4', 'place_holder': 'million', 'value': 87400000.0},
#  {'amount': '1', 'place_holder': 'million', 'value': 1000000.0},
#  {'amount': '2.6', 'place_holder': 'million', 'value': 2600000.0},
#  {'amount': '1.75', 'place_holder': 'million', 'value': 1750000.0},
#  {'amount': '28.2', 'place_holder': 'million', 'value': 28200000.0},
#  {'amount': '2,150,000', 'value': 2150000.0},
#  {'amount': '187', 'place_holder': 'million', 'value': 187000000.0},
#  {'amount': '2.1', 'place_holder': 'million', 'value': 2100000.0},
#  {'amount': '1.6', 'place_holder': 'million', 'value': 1600000.0},
#  {'amount': '1.7', 'place_holder': 'million', 'value': 1700000.0},
#  {'amount': '2.75', 'place_holder': 'million', 'value': 2750000.0},
#  {'amount': '1.75', 'place_holder': 'million', 'value': 1750000.0},
#  {'amount': '6,250,000', 'value': 6250000.0},
#  {'amount': '1.8', 'place_holder': 'million', 'value': 1800000.0},
#  {'amount': '2.5', 'place_holder': 'million', 'value': 2500000.0},
#  {'amount': '51.6', 'place_holder': 'million', 'value': 51600000.0},
#  {'amount': '12.3', 'place_holder': 'million', 'value': 12300000.0},
#  {'amount': '1,700,000', 'value': 1700000.0},
#  {'amount': '3,100,000', 'value': 3100000.0},
#  {'amount': '3.75', 'place_holder': 'million', 'value': 3750000.0},
#  {'amount': '2.3', 'place_holder': 'million', 'value': 2300000.0},
#  {'amount': '40', 'place_holder': 'million', 'value': 40000000.0},
#  {'amount': '303', 'place_holder': 'million', 'value': 303000000.0},
#  {'amount': '25.4', 'place_holder': 'million', 'value': 25400000.0},
#  {'amount': '25.1', 'place_holder': 'million', 'value': 25100000.0},
#  {'amount': '657.8', 'place_holder': 'million', 'value': 657800000.0},
#  {'amount': '213.1', 'place_holder': 'million', 'value': 213100000.0},
#  {'amount': '45.7', 'place_holder': 'million', 'value': 45700000.0},
#  {'amount': '543', 'place_holder': 'million', 'value': 543000000.0},
#  {'amount': '17.1', 'place_holder': 'million', 'value': 17100000.0},
#  {'amount': '209', 'place_holder': 'million', 'value': 209000000.0},
#  {'amount': '858', 'place_holder': 'million', 'value': 858000000.0},
#  {'place_holder': 'billion'},
#  {'amount': '332.2', 'place_holder': 'million', 'value': 332200000.0},
#  {'amount': '52.1', 'place_holder': 'million', 'value': 52100000.0},
#  {'amount': '1.024', 'place_holder': 'billion', 'value': 1024000000.0},
#  {'amount': '966.6', 'place_holder': 'million', 'value': 966600000.0},
#  {'amount': '17', 'place_holder': 'million', 'value': 17000000.0},
#  {'amount': '299.5', 'place_holder': 'million', 'value': 299500000.0},
#  {'amount': '1.029', 'place_holder': 'billion', 'value': 1028999999.9999999},
#  {'amount': '195.2', 'place_holder': 'million', 'value': 195200000.0},
#  {'amount': '143.7', 'place_holder': 'million', 'value': 143700000.0},
#  {'amount': '10.4', 'place_holder': 'million', 'value': 10400000.0},
#  {'amount': '690.8', 'place_holder': 'million', 'value': 690800000.0},
#  {'amount': '127.4', 'place_holder': 'million', 'value': 127400000.0},
#  {'amount': '1.264', 'place_holder': 'billion', 'value': 1264000000.0},
#  {'amount': '25.1', 'place_holder': 'million', 'value': 25100000.0},
#  {'amount': '794.9', 'place_holder': 'million', 'value': 794900000.0},
#  {'amount': '383.9', 'place_holder': 'million', 'value': 383900000.0},
#  {'place_holder': 'million'},
#  {'amount': '807.8', 'place_holder': 'million', 'value': 807800000.0},
#  {'amount': '133.4', 'place_holder': 'million', 'value': 133400000.0},
#  {'amount': '1.243', 'place_holder': 'billion', 'value': 1243000000.0},
#  {'amount': '197.7', 'place_holder': 'million', 'value': 197700000.0},
#  {'amount': '174', 'place_holder': 'million', 'value': 174000000.0},
#  {'amount': '529.3', 'place_holder': 'million', 'value': 529299999.99999994},
#  {'amount': '349.5', 'place_holder': 'million', 'value': 349500000.0},
#  {'amount': '353.3', 'place_holder': 'million', 'value': 353300000.0},
#  {'amount': '7.7', 'place_holder': 'million', 'value': 7700000.0},
#  {'amount': '1.051', 'place_holder': 'billion', 'value': 1050999999.9999999},
#  {'amount': '1.073', 'place_holder': 'billion', 'value': 1073000000.0},
#  {'amount': '1.657', 'place_holder': 'billion', 'value': 1657000000.0},
#  {'amount': '491.7', 'place_holder': 'million', 'value': 491700000.0},
#  {'amount': '1.450', 'place_holder': 'billion', 'value': 1450000000.0},
#  {'amount': '141.9', 'place_holder': 'million', 'value': 141900000.0},
#  {'amount': '70', 'place_holder': 'million', 'value': 70000000.0},
#  {'amount': '115.7', 'place_holder': 'million', 'value': 115700000.0}]

# %% [markdown]
# # Function: create_re_pattern()

# %%
def create_re_patterns():
    amount_pattern=re.compile('.*?\$.*?(?P<amount>[0-9,.]+)')
    place_holder_pattern = place_holder_pattern=re.compile('.*?(?P<mb>million|billion)')
    
    return (amount_pattern, place_holder_pattern)

# %% [markdown]
# # Function: create_bo_values(dictionary)

# %%
def create_bo_values(dictionary):
    
    amount_pattern, place_holder_pattern = create_re_patterns()
    
    box_office_dict = {}
    
    if dictionary.get('Box office') is not None:
        if type(dictionary.get('Box office')) is str:
            if amount_pattern.search(dictionary['Box office']) is not None:
                box_office_dict['amount'] = amount_pattern.search(dictionary['Box office']).groups()[0].strip('$')
            if place_holder_pattern.search(dictionary['Box office']) is not None:
                box_office_dict['place_holder'] = place_holder_pattern.search(dictionary['Box office']).groups()[0]
            
            if box_office_dict.get('amount') is not None:
                box_office_dict['value'] = float(box_office_dict['amount'].replace(",",""))
            
            
                if box_office_dict.get('place_holder') is not None:
                    if box_office_dict.get('place_holder') == 'million':
                        box_office_dict['value'] = box_office_dict['value']*1000000
                
                    else:
                        box_office_dict['value'] = box_office_dict['value']*1000000000
            
            if box_office_dict.get('value') is not None:
                dictionary['bov'] = box_office_dict['value']
            
    return dictionary

# %%
df[23]
# Out:
# {'title': 'rob roy, the highland rogue',
#  'Directed by': 'harold french',
#  'Produced by': ['perce pearce', 'walt disney'],
#  'Written by': 'lawrence edward watkin',
#  'Starring': ['richard todd',
#   'glynis johns',
#   'james robertson justice',
#   'michael gough',
#   'finlay currie',
#   'geoffrey keen'],
#  'Music by': 'cedric thorpe davie',
#  'Cinematography': 'guy green',
#  'Edited by': 'geoffrey foot',
#  'Production company': 'walt disney productions',
#  'Distributed by': 'rko radio pictures',
#  'Release date': ['26 october 1953 ( 1953-10-26 ) (premiere- london )',
#   '4 february 1954 ( 1954-02-04 ) ( us )'],
#  'Running time': 81,
#  'Countries': ['united kingdom', 'united states'],
#  'Language': 'english',
#  'Budget': 1800000.0}

# %%
# Create another df object to hold all dictionaries and the new 'bov' values
df_bov = [(create_bo_values(x)) for i,x in enumerate(df)]

# %%
len([x.get('bov') for i,x in enumerate(df_bov) if x.get('bov') is not None])
# Out:
# 361

# %%
len([x.get('Box office') for x in df_bov if x.get('Box office') is not None])
# Out:
# 368

# %%
len([x for x in df_bov if x.get('Box office') is not None and x.get('bov') is None])
# Out:
# 7

# %%
[(i,x.get('title'),x.get('Box office')) for i,x in enumerate(df_bov) if x.get('Box office') is not None and x.get('bov') is None]
# Out:
# [(42, "darby o'gill and the little people", ['[2]', '[3]']),
#  (113, 'herbie rides again', ['[1]']),
#  (141, 'the black hole', ['[1]']),
#  (284, "howl's moving castle", ['¥', '[3]']),
#  (383, 'abcd 2', 'est. ₹1.65 billion'),
#  (395, 'dangal', ['[4]', '[5]', '[6]', '[7]', '[8]']),
#  (402, 'jagga jasoos', '₹ 833.5 million')]

# %% [markdown]
#  going to the wiki pages for the movies we will insert the values for the movies we are able to insert.

# %%
df_bov[42]['bov'] = 2600000.0
df_bov[113]['bov'] = 30800000.0
df_bov[141]['bov'] = 35800000.0
df_bov[284]['bov'] = 236000000.0
df_bov[395]['bov'] = 311000000.0
